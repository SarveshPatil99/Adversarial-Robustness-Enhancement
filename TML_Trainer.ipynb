# %% [markdown]
# <a href="https://colab.research.google.com/github/SarveshPatil99/Adversarial-Robustness-Enhancement/blob/main/TML_Trainer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Default title text
download_data = True # @param {type:"boolean"}
sg_type = "StyleGANv3" # @param ["StyleGANv2", "StyleGANv3"]
dataset_size = "20k" # @param ["10k", "20k"] {type:"string"}

sg_dict = {
    "StyleGANv2": {
        "10k": "https://drive.google.com/uc?id=1ZBxnHMArN2-HAdViUFKarKxuXVk4sREk"
    },
    "StyleGANv3": {
        "10k": "https://drive.google.com/uc?id=1-BTtMGzH8925FtIu20KbkfmmSz3LNTer",
        "20k": "https://drive.google.com/uc?id=18MZZwgKjTGlB2Y4Esw_lRIvbpOaANbnh"
    }
}

if download_data:
  # !pip -q install image-classifiers
  import os
  # !gdown {sg_dict[sg_type][dataset_size]}
  zipfile_name = [f for f in os.listdir() if f.endswith('.zip' )][0]
  # !unzip -q {zipfile_name}
  # !rm {zipfile_name}
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 3.3 MB/s eta 0:00:00
# Downloading...
# From: https://drive.google.com/uc?id=18MZZwgKjTGlB2Y4Esw_lRIvbpOaANbnh
# To: /content/original_dataset_stylegan3_10000.zip
# 100% 2.12G/2.12G [00:24<00:00, 87.7MB/s]

# %%
import tensorflow as tf
import numpy as np
import pathlib
import os
from tensorflow.keras.layers import Input, Conv2D, SeparableConv2D, MaxPooling2D, BatchNormalization, Dropout, Flatten, Dense, ReLU, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import RMSprop
import pickle
from matplotlib import pyplot as plt
from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy('mixed_float16')

# %%
dataset_name = 'original'
train_dir = pathlib.Path(f'{dataset_name}/train')
val_dir = pathlib.Path(f'{dataset_name}/val')
test_dir = pathlib.Path(f'{dataset_name}/test')
train_len = len(list(train_dir.glob('*/*.png')))
val_len = len(list(val_dir.glob('*/*.png')))
classes = np.array(os.listdir(f'{dataset_name}/train'))
class_dict = dict(zip(classes,range(len(classes))))
print(train_len, val_len)
print(class_dict)

img_height = 256
img_width = 256
batch_size = 16

perc_chance = 50 # 0-100 chance of augmentation

noise_params = {
    'gaussian': {'stddev': 0.05},
    'saltpepper': {'pepper_thresh': 0.05,'salt_thresh': 0.05},
    'speckle': {'stddev': 0.05},
    'poisson': {'lambda': 0.5}
}

# Noise functions

def noise_gaussian(image):
  stddev = noise_params['gaussian']['stddev']
  noise = tf.random.normal(shape=tf.shape(image), mean=0, stddev=stddev)
  image = image + noise
  image = tf.clip_by_value(image, 0, 1)
  return image

def noise_poisson(image):
  # lam = noise_params['poisson']['lambda']
  # noise = tf.random.poisson(shape=tf.shape(image), lam=lam)
  # image = image + noise
  # image = tf.clip_by_value(image, 0, 1)
  return image

def noise_saltpepper(image):
  pepper_thresh = noise_params['saltpepper']['pepper_thresh']
  salt_thresh = noise_params['saltpepper']['salt_thresh']

  noise_map = tf.random.uniform((256,256))
  pepper_map = tf.cast(noise_map < pepper_thresh, tf.float32)
  pepper_map = tf.stack([pepper_map]*3,-1)
  salt_map = tf.cast(noise_map > (1-salt_thresh), tf.float32)
  salt_map = tf.stack([salt_map]*3,-1)

  image = image - 2*pepper_map
  image = image + 2*salt_map
  image = tf.clip_by_value(image, 0, 1)

  return image

def noise_speckle(image):
  stddev = noise_params['gaussian']['stddev']
  noise = tf.random.normal(shape=tf.shape(image), mean=0, stddev=stddev)
  image = image + image*noise
  image = tf.clip_by_value(image, 0, 1)
  return image

noise_func = None

def create_label(image_path):
  class_name = tf.strings.split(image_path,'/')[-2]
  return tf.cast(classes == class_name,tf.float32)

def load(image_path):

  image = tf.io.read_file(image_path)
  image = tf.image.decode_png(image) / 255
  # image = tf.image.resize(image, [img_height, img_width])

  chance = tf.random.uniform(shape=[], minval=0, maxval=100, dtype=tf.int64) < perc_chance
  if noise_func and chance:
    image = noise_func(image)

  label = create_label(image_path)

  return image, label

train_ds = tf.data.Dataset.list_files(str(train_dir/'*/*'), shuffle=False)
train_ds = train_ds.shuffle(len(train_ds), reshuffle_each_iteration=False)
train_ds = train_ds.map(load, num_parallel_calls=tf.data.AUTOTUNE)
# train_ds = train_ds.cache('tmp')
train_ds = train_ds.batch(batch_size)
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE)
train_ds_length = len(train_ds)

val_ds = tf.data.Dataset.list_files(str(val_dir/'*/*'), shuffle=False)
val_ds = val_ds.shuffle(len(val_ds), reshuffle_each_iteration=False)
val_ds = val_ds.map(load, num_parallel_calls=tf.data.AUTOTUNE)
val_ds = val_ds.cache()
val_ds = val_ds.batch(batch_size)
val_ds_length = len(val_ds)

print(f'train_ds_length: {train_ds_length}, val_ds_length: {val_ds_length}')
# Out:
# 16000 2000
# {'fake': 0, 'real': 1}
# train_ds_length: 1000, val_ds_length: 125

# %%
for x, y in train_ds.take(1):
  pass
# plt.figure(figsize=(32,10))
plt.figure(figsize=(8,2))
for i in range(4):
  plt.subplot(1,4,i+1)
  plt.imshow(x[i])
  plt.axis('off')
  plt.title(classes[tf.argmax(y[i])])
plt.tight_layout()

# %%
def conv_bn_relu(filters,x,idx,label):
    x = SeparableConv2D(filters, 3, padding='same', kernel_initializer='he_uniform',name=f'conv_{idx}{label}')(x)
    x = BatchNormalization(name=f'bn_{idx}{label}')(x)
    x = ReLU(name=f'relu_{idx}{label}')(x)
    # x = Dropout(rate=0.1,name=f'dropout_{idx}{label}')(x)
    return x

def create_model(input_shape = (256, 256, 3)):
  input_layer = Input(input_shape,name='input')
  n_filters = 8
  x = input_layer
  for i in range(5):
    x = conv_bn_relu(n_filters,x,i,'a')
    x = conv_bn_relu(n_filters,x,i,'b')
    x = MaxPooling2D(name=f'maxpool_{i}')(x)
    n_filters = int(n_filters*2)
  # x = Flatten(name='flatten')(x)
  x = GlobalAveragePooling2D(name='global_pool')(x)
  # x = Dense(32,activation='relu',name='dense_0')(x)
  # x = Dropout(rate=0.2,name=f'dropout_dense')(x)
  x = Dense(2,activation='softmax',name='dense_0', dtype = 'float32')(x)

  model = Model(inputs = [input_layer], outputs = [x])

  return model

# %%
lr = 1e-3
epochs = 50
rLR_patience = 5
es_patience = 10
loss = 'categorical_crossentropy'
metrics = ['accuracy']
n_filters = 8
model_type = 'snp'

if sg_type == 'StyleGANv2':
  model_filename = f'{model_type}_sg2={dataset_size}_n={n_filters}_epoch={epochs}_lr={lr:.0e}'
elif sg_type == 'StyleGANv3':
  model_filename = f'{model_type}_sg3={dataset_size}_n={n_filters}_epoch={epochs}_lr={lr:.0e}'

model_path = f'saved/models/{model_filename}.h5'
history_path = f'saved/histories/{model_filename}.pkl'
pathlib.Path('saved/models').mkdir(exist_ok=True,parents=True)
pathlib.Path('saved/histories').mkdir(exist_ok=True,parents=True)

checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_accuracy', mode='max', save_best_only=True, verbose = 1)
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', mode = 'max', factor=1/np.sqrt(10), patience = rLR_patience, min_lr=1e-6, verbose = 1)
earlystopper = EarlyStopping(monitor='val_accuracy', mode = 'max', patience = es_patience, verbose=1)
callbacks = [checkpoint, reduce_lr, earlystopper]

model = create_model()
print(model.count_params())
optimizer = RMSprop(learning_rate = lr)
model.compile(optimizer = optimizer, loss = loss, metrics = metrics)
hist = model.fit(train_ds, epochs = epochs, validation_data = val_ds, callbacks = callbacks, verbose = 1)
with open(history_path, 'wb') as file_pi:
  pickle.dump(hist.history, file_pi)
# Out:
# 38805
# Epoch 1/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.7066 - accuracy: 0.4952
# Epoch 1: val_accuracy improved from -inf to 0.50000, saving model to saved/models/snp_sg3=20k_n=8_epoch=50_lr=1e-03.h5
# 1000/1000 [==============================] - 92s 85ms/step - loss: 0.7066 - accuracy: 0.4952 - val_loss: 0.6984 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 2/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.6979 - accuracy: 0.5006
# Epoch 2: val_accuracy improved from 0.50000 to 0.50200, saving model to saved/models/snp_sg3=20k_n=8_epoch=50_lr=1e-03.h5
# 1000/1000 [==============================] - 73s 73ms/step - loss: 0.6979 - accuracy: 0.5006 - val_loss: 0.6966 - val_accuracy: 0.5020 - lr: 0.0010
# Epoch 3/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.6970 - accuracy: 0.5003
# Epoch 3: val_accuracy improved from 0.50200 to 0.51200, saving model to saved/models/snp_sg3=20k_n=8_epoch=50_lr=1e-03.h5
# 1000/1000 [==============================] - 73s 73ms/step - loss: 0.6970 - accuracy: 0.5003 - val_loss: 0.7057 - val_accuracy: 0.5120 - lr: 0.0010
# Epoch 4/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.6973 - accuracy: 0.5021
# Epoch 4: val_accuracy did not improve from 0.51200
# 1000/1000 [==============================] - 73s 73ms/step - loss: 0.6973 - accuracy: 0.5021 - val_loss: 0.6939 - val_accuracy: 0.4975 - lr: 0.0010
# Epoch 5/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.6976 - accuracy: 0.5008
# Epoch 5: val_accuracy did not improve from 0.51200
# 1000/1000 [==============================] - 73s 73ms/step - loss: 0.6976 - accuracy: 0.5008 - val_loss: 0.6947 - val_accuracy: 0.5045 - lr: 0.0010
# Epoch 6/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.6965 - accuracy: 0.4987
# Epoch 6: val_accuracy did not improve from 0.51200
# 1000/1000 [==============================] - 74s 74ms/step - loss: 0.6965 - accuracy: 0.4987 - val_loss: 0.6987 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 7/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.6965 - accuracy: 0.4999
# Epoch 7: val_accuracy did not improve from 0.51200
# 1000/1000 [==============================] - 72s 72ms/step - loss: 0.6965 - accuracy: 0.4999 - val_loss: 0.7847 - val_accuracy: 0.5080 - lr: 0.0010
# Epoch 8/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.6960 - accuracy: 0.5046
# Epoch 8: val_accuracy improved from 0.51200 to 0.51450, saving model to saved/models/snp_sg3=20k_n=8_epoch=50_lr=1e-03.h5
# 1000/1000 [==============================] - 71s 71ms/step - loss: 0.6960 - accuracy: 0.5046 - val_loss: 0.6936 - val_accuracy: 0.5145 - lr: 0.0010
# Epoch 9/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.6962 - accuracy: 0.5064
# Epoch 9: val_accuracy did not improve from 0.51450
# 1000/1000 [==============================] - 74s 74ms/step - loss: 0.6962 - accuracy: 0.5064 - val_loss: 0.6952 - val_accuracy: 0.5025 - lr: 0.0010
# Epoch 10/50
#  999/1000 [============================>.] - ETA: 0s - loss: 0.6956 - accuracy: 0.5038
# Epoch 10: val_accuracy did not improve from 0.51450
# 1000/1000 [==============================] - 72s 72ms/step - loss: 0.6956 - accuracy: 0.5036 - val_loss: 0.6942 - val_accuracy: 0.5030 - lr: 0.0010
# Epoch 11/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.6955 - accuracy: 0.5042
# Epoch 11: val_accuracy did not improve from 0.51450
# 1000/1000 [==============================] - 73s 73ms/step - loss: 0.6955 - accuracy: 0.5042 - val_loss: 0.6932 - val_accuracy: 0.5085 - lr: 0.0010
# Epoch 12/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.6952 - accuracy: 0.5064
# Epoch 12: val_accuracy did not improve from 0.51450
# 1000/1000 [==============================] - 74s 73ms/step - loss: 0.6952 - accuracy: 0.5064 - val_loss: 0.6940 - val_accuracy: 0.5005 - lr: 0.0010
# Epoch 13/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.6962 - accuracy: 0.4978
# Epoch 13: val_accuracy did not improve from 0.51450
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.00031622778103685084.
# 1000/1000 [==============================] - 73s 73ms/step - loss: 0.6962 - accuracy: 0.4978 - val_loss: 0.6937 - val_accuracy: 0.4995 - lr: 0.0010
# Epoch 14/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.6938 - accuracy: 0.5058
# Epoch 14: val_accuracy improved from 0.51450 to 0.52200, saving model to saved/models/snp_sg3=20k_n=8_epoch=50_lr=1e-03.h5
# 1000/1000 [==============================] - 72s 72ms/step - loss: 0.6938 - accuracy: 0.5058 - val_loss: 0.6941 - val_accuracy: 0.5220 - lr: 3.1623e-04
# Epoch 15/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.5063
# Epoch 15: val_accuracy did not improve from 0.52200
# 1000/1000 [==============================] - 72s 71ms/step - loss: 0.6935 - accuracy: 0.5063 - val_loss: 0.6950 - val_accuracy: 0.5215 - lr: 3.1623e-04
# Epoch 16/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.5053
# Epoch 16: val_accuracy did not improve from 0.52200
# 1000/1000 [==============================] - 73s 73ms/step - loss: 0.6936 - accuracy: 0.5053 - val_loss: 0.6954 - val_accuracy: 0.4905 - lr: 3.1623e-04
# Epoch 17/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.5052
# Epoch 17: val_accuracy did not improve from 0.52200
# 1000/1000 [==============================] - 72s 72ms/step - loss: 0.6934 - accuracy: 0.5052 - val_loss: 0.6963 - val_accuracy: 0.4870 - lr: 3.1623e-04
# Epoch 18/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.6935 - accuracy: 0.5089
# Epoch 18: val_accuracy did not improve from 0.52200
# 1000/1000 [==============================] - 72s 71ms/step - loss: 0.6935 - accuracy: 0.5089 - val_loss: 0.6958 - val_accuracy: 0.4950 - lr: 3.1623e-04
# Epoch 19/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.6934 - accuracy: 0.5129
# Epoch 19: val_accuracy did not improve from 0.52200
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.00010000000639606199.
# 1000/1000 [==============================] - 72s 72ms/step - loss: 0.6934 - accuracy: 0.5129 - val_loss: 0.6948 - val_accuracy: 0.5115 - lr: 3.1623e-04
# Epoch 20/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.6920 - accuracy: 0.5213
# Epoch 20: val_accuracy did not improve from 0.52200
# 1000/1000 [==============================] - 73s 73ms/step - loss: 0.6920 - accuracy: 0.5213 - val_loss: 0.6974 - val_accuracy: 0.5005 - lr: 1.0000e-04
# Epoch 21/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.6916 - accuracy: 0.5232
# Epoch 21: val_accuracy did not improve from 0.52200
# 1000/1000 [==============================] - 73s 73ms/step - loss: 0.6916 - accuracy: 0.5232 - val_loss: 0.6968 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 22/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.6912 - accuracy: 0.5247
# Epoch 22: val_accuracy did not improve from 0.52200
# 1000/1000 [==============================] - 73s 73ms/step - loss: 0.6912 - accuracy: 0.5247 - val_loss: 0.6981 - val_accuracy: 0.4945 - lr: 1.0000e-04
# Epoch 23/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.6911 - accuracy: 0.5271
# Epoch 23: val_accuracy did not improve from 0.52200
# 1000/1000 [==============================] - 73s 73ms/step - loss: 0.6911 - accuracy: 0.5271 - val_loss: 0.6990 - val_accuracy: 0.5115 - lr: 1.0000e-04
# Epoch 24/50
# 1000/1000 [==============================] - ETA: 0s - loss: 0.6903 - accuracy: 0.5335
# Epoch 24: val_accuracy did not improve from 0.52200
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 3.1622778103685084e-05.
# 1000/1000 [==============================] - 73s 73ms/step - loss: 0.6903 - accuracy: 0.5335 - val_loss: 0.6995 - val_accuracy: 0.5130 - lr: 1.0000e-04
# Epoch 24: early stopping

# %%
model.load_weights(model_path)
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'])
plt.show()
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'])
plt.show()

# %%
from tensorflow.keras.models import load_model
model = load_model(model_path)
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %%
test_ds = tf.data.Dataset.list_files(str(test_dir/'*/*'), shuffle=False)
test_ds = test_ds.shuffle(len(test_ds), reshuffle_each_iteration=False)
test_ds = test_ds.map(load, num_parallel_calls=tf.data.AUTOTUNE)
test_ds = test_ds.cache()
test_ds = test_ds.batch(batch_size)
test_ds_length = len(test_ds)

print(f'test_ds_length: {test_ds_length}')
# Out:
# test_ds_length: 63

# %%
model.evaluate(test_ds)
# Out:
# 63/63 [==============================] - 4s 57ms/step - loss: 0.7933 - accuracy: 0.5970
# [0.7933207750320435, 0.597000002861023]
