# %% [markdown]
# <a href="https://colab.research.google.com/github/SarveshPatil99/Adversarial-Robustness-Enhancement/blob/main/TML_Trainer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title Default title text
download_data = True # @param {type:"boolean"}
sg_type = "StyleGANv3" # @param ["StyleGANv2", "StyleGANv3"]
dataset_size = "20k" # @param ["10k", "20k"] {type:"string"}

sg_dict = {
    "StyleGANv2": {
        "10k": "https://drive.google.com/uc?id=1ZBxnHMArN2-HAdViUFKarKxuXVk4sREk"
    },
    "StyleGANv3": {
        "10k": "https://drive.google.com/uc?id=1-BTtMGzH8925FtIu20KbkfmmSz3LNTer",
        "20k": "https://drive.google.com/uc?id=18MZZwgKjTGlB2Y4Esw_lRIvbpOaANbnh"
    }
}

if download_data:
  # !pip -q install image-classifiers
  import os
  # !gdown {sg_dict[sg_type][dataset_size]}
  zipfile_name = [f for f in os.listdir() if f.endswith('.zip' )][0]
  # !unzip -q {zipfile_name}
  # !rm {zipfile_name}
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 2.6 MB/s eta 0:00:00
# Downloading...
# From: https://drive.google.com/uc?id=18MZZwgKjTGlB2Y4Esw_lRIvbpOaANbnh
# To: /content/original_dataset_stylegan3_10000.zip
# 100% 2.12G/2.12G [00:28<00:00, 73.9MB/s]

# %%
# StyleGAN2 - 5000
# !gdown https://drive.google.com/uc?id=1ZBxnHMArN2-HAdViUFKarKxuXVk4sREk
# !unzip -q original_dataset_stylegan2_5000.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ZBxnHMArN2-HAdViUFKarKxuXVk4sREk
# To: /content/original_dataset_stylegan2_5000.zip
# 100% 1.08G/1.08G [00:11<00:00, 91.3MB/s]

# %%
# StyleGAN3 - 10000
# !gdown https://drive.google.com/uc?id=18MZZwgKjTGlB2Y4Esw_lRIvbpOaANbnh
# !unzip -q original_dataset_stylegan3_10000.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=18MZZwgKjTGlB2Y4Esw_lRIvbpOaANbnh
# To: /content/original_dataset_stylegan3_10000.zip
# 100% 2.12G/2.12G [00:25<00:00, 84.5MB/s]

# %%
# StyleGAN3 - 5000
# !gdown https://drive.google.com/uc?id=1-BTtMGzH8925FtIu20KbkfmmSz3LNTer
# !unzip -q /content/original_dataset_stylegan3_5000.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1-BTtMGzH8925FtIu20KbkfmmSz3LNTer
# To: /content/original_dataset_stylegan3_5000.zip
# 100% 1.06G/1.06G [00:12<00:00, 82.8MB/s]

# %%
import tensorflow as tf
import numpy as np
import pathlib
import os
from tensorflow.keras.layers import Input, Conv2D, SeparableConv2D, MaxPooling2D, BatchNormalization, Dropout, Flatten, Dense, ReLU, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import RMSprop
import pickle
from matplotlib import pyplot as plt
from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy('mixed_float16')

# %%
dataset_name = 'original'
train_dir = pathlib.Path(f'{dataset_name}/train')
val_dir = pathlib.Path(f'{dataset_name}/val')
test_dir = pathlib.Path(f'{dataset_name}/test')
train_len = len(list(train_dir.glob('*/*.png')))
val_len = len(list(val_dir.glob('*/*.png')))
classes = np.array(os.listdir(f'{dataset_name}/train'))
class_dict = dict(zip(classes,range(len(classes))))
print(train_len, val_len)
print(class_dict)

img_height = 256
img_width = 256
batch_size = 16

noise_params = {
    'gaussian': {'stddev': 0.05},
    'saltpepper': {'pepper_thresh': 0.025,'salt_thresh': 0.025},
    'speckle': {'stddev': 0.05},
    'poisson': {'lambda': 0.5}
}

# Noise functions

def noise_gaussian(image):
  stddev = noise_params['gaussian']['stddev']
  noise = tf.random.normal(shape=tf.shape(image), mean=0, stddev=stddev)
  image = image + noise
  image = tf.clip_by_value(image, 0, 1)
  return image

def noise_poisson(image):
  # lam = noise_params['poisson']['lambda']
  # noise = tf.random.poisson(shape=tf.shape(image), lam=lam)
  # image = image + noise
  # image = tf.clip_by_value(image, 0, 1)
  return image

def noise_saltpepper(image):
  pepper_thresh = noise_params['saltpepper']['pepper_thresh']
  salt_thresh = noise_params['saltpepper']['salt_thresh']

  noise_map = tf.random.uniform((256,256))
  pepper_map = tf.cast(noise_map < pepper_thresh, tf.float32)
  pepper_map = tf.stack([pepper_map]*3,-1)
  salt_map = tf.cast(noise_map > (1-salt_thresh), tf.float32)
  salt_map = tf.stack([salt_map]*3,-1)

  image = image - 2*pepper_map
  image = image + 2*salt_map
  image = tf.clip_by_value(image, 0, 1)

  return image

def noise_speckle(image):
  stddev = noise_params['gaussian']['stddev']
  noise = tf.random.normal(shape=tf.shape(image), mean=0, stddev=stddev)
  image = image + image*noise
  image = tf.clip_by_value(image, 0, 1)
  return image

noise_func = None

def create_label(image_path):
  class_name = tf.strings.split(image_path,'/')[-2]
  return tf.cast(classes == class_name,tf.float32)

def load(image_path):

  image = tf.io.read_file(image_path)
  image = tf.image.decode_png(image) / 255
  # image = tf.image.resize(image, [img_height, img_width])

  if noise_func:
    image = noise_func(image)

  label = create_label(image_path)

  return image, label

train_ds = tf.data.Dataset.list_files(str(train_dir/'*/*'), shuffle=False)
train_ds = train_ds.shuffle(len(train_ds), reshuffle_each_iteration=False)
train_ds = train_ds.map(load, num_parallel_calls=tf.data.AUTOTUNE)
# train_ds = train_ds.cache('tmp')
train_ds = train_ds.batch(batch_size)
train_ds = train_ds.prefetch(buffer_size=tf.data.AUTOTUNE)
train_ds_length = len(train_ds)

val_ds = tf.data.Dataset.list_files(str(val_dir/'*/*'), shuffle=False)
val_ds = val_ds.shuffle(len(val_ds), reshuffle_each_iteration=False)
val_ds = val_ds.map(load, num_parallel_calls=tf.data.AUTOTUNE)
val_ds = val_ds.cache()
val_ds = val_ds.batch(batch_size)
val_ds_length = len(val_ds)

print(f'train_ds_length: {train_ds_length}, val_ds_length: {val_ds_length}')
# Out:
# 16000 2000
# {'fake': 0, 'real': 1}
# train_ds_length: 1000, val_ds_length: 125

# %%
for x, y in train_ds.take(1):
  pass
# plt.figure(figsize=(32,10))
plt.figure(figsize=(8,2))
for i in range(4):
  plt.subplot(1,4,i+1)
  plt.imshow(x[i])
  plt.axis('off')
  plt.title(classes[tf.argmax(y[i])])
plt.tight_layout()

# %%
def conv_bn_relu(filters,x,idx,label):
    x = SeparableConv2D(filters, 3, padding='same', kernel_initializer='he_uniform',name=f'conv_{idx}{label}')(x)
    x = BatchNormalization(name=f'bn_{idx}{label}')(x)
    x = ReLU(name=f'relu_{idx}{label}')(x)
    x = Dropout(rate=0.1,name=f'dropout_{idx}{label}')(x)
    return x

def create_model(input_shape = (256, 256, 3)):
  input_layer = Input(input_shape,name='input')
  n_filters = 16
  x = input_layer
  for i in range(5):
    x = conv_bn_relu(n_filters,x,i,'a')
    x = conv_bn_relu(n_filters,x,i,'b')
    x = MaxPooling2D(name=f'maxpool_{i}')(x)
    n_filters = int(n_filters*2)
  # x = Flatten(name='flatten')(x)
  x = GlobalAveragePooling2D(name='global_pool')(x)
  # x = Dense(32,activation='relu',name='dense_0')(x)
  # x = Dropout(rate=0.2,name=f'dropout_dense')(x)
  x = Dense(2,activation='softmax',name='dense_0', dtype = 'float32')(x)

  model = Model(inputs = [input_layer], outputs = [x])

  return model

# %%
lr = 1e-3
epochs = 100
rLR_patience = 15
es_patience = 40
loss = 'categorical_crossentropy'
metrics = ['accuracy']

if sg_type == 'StyleGANv2':
  model_filename = f'baseline_sg2={dataset_size}_n=16_epoch={epochs}_lr={lr:.0e}'
elif sg_type == 'StyleGANv3':
  model_filename = f'baseline_sg3={dataset_size}_n=16_epoch={epochs}_lr={lr:.0e}'

model_path = f'saved/models/{model_filename}.h5'
history_path = f'saved/histories/{model_filename}.pkl'
pathlib.Path('saved/models').mkdir(exist_ok=True,parents=True)
pathlib.Path('saved/histories').mkdir(exist_ok=True,parents=True)

checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_accuracy', mode='max', save_best_only=True, verbose = 1)
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', mode = 'max', factor=1/np.sqrt(10), patience = rLR_patience, min_lr=1e-6, verbose = 1)
earlystopper = EarlyStopping(monitor='val_accuracy', mode = 'max', patience = es_patience, verbose=1)
callbacks = [checkpoint, reduce_lr, earlystopper]

model = create_model()
print(model.count_params())
optimizer = RMSprop(learning_rate = lr)
model.compile(optimizer = optimizer, loss = loss, metrics = metrics)
hist = model.fit(train_ds, epochs = epochs, validation_data = val_ds, callbacks = callbacks, verbose = 1)
with open(history_path, 'wb') as file_pi:
  pickle.dump(hist.history, file_pi)
# Out:
# 142989
# Epoch 1/100
# 500/500 [==============================] - ETA: 0s - loss: 0.7380 - accuracy: 0.4959
# Epoch 1: val_accuracy improved from -inf to 0.49900, saving model to saved/models/baseline_sg3=10k_n=16_epoch=100_lr=1e-03.h5
# 500/500 [==============================] - 38s 59ms/step - loss: 0.7380 - accuracy: 0.4959 - val_loss: 0.6934 - val_accuracy: 0.4990 - lr: 0.0010
# Epoch 2/100
# 500/500 [==============================] - ETA: 0s - loss: 0.7233 - accuracy: 0.5042
# Epoch 2: val_accuracy improved from 0.49900 to 0.52400, saving model to saved/models/baseline_sg3=10k_n=16_epoch=100_lr=1e-03.h5
# 500/500 [==============================] - 30s 59ms/step - loss: 0.7233 - accuracy: 0.5042 - val_loss: 0.7882 - val_accuracy: 0.5240 - lr: 0.0010
# Epoch 3/100
# 500/500 [==============================] - ETA: 0s - loss: 0.7111 - accuracy: 0.5016
# Epoch 3: val_accuracy did not improve from 0.52400
# 500/500 [==============================] - 30s 59ms/step - loss: 0.7111 - accuracy: 0.5016 - val_loss: 0.8083 - val_accuracy: 0.5170 - lr: 0.0010
# Epoch 4/100
# 500/500 [==============================] - ETA: 0s - loss: 0.7076 - accuracy: 0.5021
# Epoch 4: val_accuracy did not improve from 0.52400
# 500/500 [==============================] - 30s 59ms/step - loss: 0.7076 - accuracy: 0.5021 - val_loss: 0.7264 - val_accuracy: 0.5020 - lr: 0.0010
# Epoch 5/100
# 500/500 [==============================] - ETA: 0s - loss: 0.7049 - accuracy: 0.4974
# Epoch 5: val_accuracy did not improve from 0.52400
# 500/500 [==============================] - 30s 60ms/step - loss: 0.7049 - accuracy: 0.4974 - val_loss: 0.6944 - val_accuracy: 0.4980 - lr: 0.0010
# Epoch 6/100
# 500/500 [==============================] - ETA: 0s - loss: 0.7012 - accuracy: 0.5128
# Epoch 6: val_accuracy did not improve from 0.52400
# 500/500 [==============================] - 30s 60ms/step - loss: 0.7012 - accuracy: 0.5128 - val_loss: 0.6959 - val_accuracy: 0.4990 - lr: 0.0010
# Epoch 7/100
# 500/500 [==============================] - ETA: 0s - loss: 0.7023 - accuracy: 0.5029
# Epoch 7: val_accuracy did not improve from 0.52400
# 500/500 [==============================] - 30s 60ms/step - loss: 0.7023 - accuracy: 0.5029 - val_loss: 0.6958 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 8/100
# 500/500 [==============================] - ETA: 0s - loss: 0.7012 - accuracy: 0.5006
# Epoch 8: val_accuracy did not improve from 0.52400
# 500/500 [==============================] - 30s 60ms/step - loss: 0.7012 - accuracy: 0.5006 - val_loss: 0.7171 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 9/100
# 500/500 [==============================] - ETA: 0s - loss: 0.6999 - accuracy: 0.5006
# Epoch 9: val_accuracy did not improve from 0.52400
# 500/500 [==============================] - 30s 60ms/step - loss: 0.6999 - accuracy: 0.5006 - val_loss: 0.7278 - val_accuracy: 0.4980 - lr: 0.0010
# Epoch 10/100
# 500/500 [==============================] - ETA: 0s - loss: 0.6994 - accuracy: 0.4939
# Epoch 10: val_accuracy did not improve from 0.52400
# 500/500 [==============================] - 30s 60ms/step - loss: 0.6994 - accuracy: 0.4939 - val_loss: 0.6954 - val_accuracy: 0.5100 - lr: 0.0010
# Epoch 11/100
# 500/500 [==============================] - ETA: 0s - loss: 0.6988 - accuracy: 0.4978
# Epoch 11: val_accuracy did not improve from 0.52400
# 500/500 [==============================] - 30s 60ms/step - loss: 0.6988 - accuracy: 0.4978 - val_loss: 0.6942 - val_accuracy: 0.4970 - lr: 0.0010
# Epoch 12/100
# 500/500 [==============================] - ETA: 0s - loss: 0.6970 - accuracy: 0.5084
# Epoch 12: val_accuracy did not improve from 0.52400
# 500/500 [==============================] - 30s 60ms/step - loss: 0.6970 - accuracy: 0.5084 - val_loss: 0.6966 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 13/100
# 500/500 [==============================] - ETA: 0s - loss: 0.6979 - accuracy: 0.4986
# Epoch 13: val_accuracy did not improve from 0.52400
# 500/500 [==============================] - 30s 60ms/step - loss: 0.6979 - accuracy: 0.4986 - val_loss: 0.6948 - val_accuracy: 0.4990 - lr: 0.0010
# Epoch 14/100
# 500/500 [==============================] - ETA: 0s - loss: 0.6977 - accuracy: 0.5008
# Epoch 14: val_accuracy did not improve from 0.52400
# 500/500 [==============================] - 30s 60ms/step - loss: 0.6977 - accuracy: 0.5008 - val_loss: 0.6962 - val_accuracy: 0.4990 - lr: 0.0010
# Epoch 15/100
# 500/500 [==============================] - ETA: 0s - loss: 0.6969 - accuracy: 0.5067
# Epoch 15: val_accuracy did not improve from 0.52400
# 500/500 [==============================] - 30s 60ms/step - loss: 0.6969 - accuracy: 0.5067 - val_loss: 0.6950 - val_accuracy: 0.5080 - lr: 0.0010
# Epoch 16/100
# 500/500 [==============================] - ETA: 0s - loss: 0.6967 - accuracy: 0.5030
# Epoch 16: val_accuracy did not improve from 0.52400
# 500/500 [==============================] - 30s 60ms/step - loss: 0.6967 - accuracy: 0.5030 - val_loss: 0.6955 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 17/100
# 500/500 [==============================] - ETA: 0s - loss: 0.6958 - accuracy: 0.5094
# Epoch 17: val_accuracy did not improve from 0.52400
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.00031622778103685084.
# 500/500 [==============================] - 30s 61ms/step - loss: 0.6958 - accuracy: 0.5094 - val_loss: 0.6940 - val_accuracy: 0.5080 - lr: 0.0010
# Epoch 18/100
# 500/500 [==============================] - ETA: 0s - loss: 0.6937 - accuracy: 0.5096
# Epoch 18: val_accuracy did not improve from 0.52400
# 500/500 [==============================] - 30s 60ms/step - loss: 0.6937 - accuracy: 0.5096 - val_loss: 0.6928 - val_accuracy: 0.5100 - lr: 3.1623e-04
# Epoch 19/100
# 500/500 [==============================] - ETA: 0s - loss: 0.6929 - accuracy: 0.5130
# Epoch 19: val_accuracy did not improve from 0.52400
# 500/500 [==============================] - 30s 61ms/step - loss: 0.6929 - accuracy: 0.5130 - val_loss: 0.6930 - val_accuracy: 0.5120 - lr: 3.1623e-04
# Epoch 20/100
# 500/500 [==============================] - ETA: 0s - loss: 0.6922 - accuracy: 0.5195
# Epoch 20: val_accuracy did not improve from 0.52400
# 500/500 [==============================] - 30s 60ms/step - loss: 0.6922 - accuracy: 0.5195 - val_loss: 0.6938 - val_accuracy: 0.5040 - lr: 3.1623e-04
# Epoch 21/100
# 500/500 [==============================] - ETA: 0s - loss: 0.6914 - accuracy: 0.5145
# Epoch 21: val_accuracy did not improve from 0.52400
# 500/500 [==============================] - 30s 60ms/step - loss: 0.6914 - accuracy: 0.5145 - val_loss: 0.6942 - val_accuracy: 0.5040 - lr: 3.1623e-04
# Epoch 22/100
# 500/500 [==============================] - ETA: 0s - loss: 0.6920 - accuracy: 0.5170
# Epoch 22: val_accuracy did not improve from 0.52400
# 500/500 [==============================] - 30s 60ms/step - loss: 0.6920 - accuracy: 0.5170 - val_loss: 0.6947 - val_accuracy: 0.5070 - lr: 3.1623e-04
# Epoch 23/100
# 500/500 [==============================] - ETA: 0s - loss: 0.6912 - accuracy: 0.5222
# Epoch 23: val_accuracy did not improve from 0.52400
# 500/500 [==============================] - 31s 61ms/step - loss: 0.6912 - accuracy: 0.5222 - val_loss: 0.6952 - val_accuracy: 0.5020 - lr: 3.1623e-04
# Epoch 24/100
# 500/500 [==============================] - ETA: 0s - loss: 0.6910 - accuracy: 0.5244
# Epoch 24: val_accuracy did not improve from 0.52400
# 500/500 [==============================] - 30s 60ms/step - loss: 0.6910 - accuracy: 0.5244 - val_loss: 0.6954 - val_accuracy: 0.5050 - lr: 3.1623e-04
# Epoch 25/100
# 500/500 [==============================] - ETA: 0s - loss: 0.6904 - accuracy: 0.5254
# Epoch 25: val_accuracy did not improve from 0.52400
# 500/500 [==============================] - 31s 62ms/step - loss: 0.6904 - accuracy: 0.5254 - val_loss: 0.6952 - val_accuracy: 0.5060 - lr: 3.1623e-04
# Epoch 26/100
# 500/500 [==============================] - ETA: 0s - loss: 0.6903 - accuracy: 0.5297
# Epoch 26: val_accuracy did not improve from 0.52400
# 500/500 [==============================] - 30s 61ms/step - loss: 0.6903 - accuracy: 0.5297 - val_loss: 0.6941 - val_accuracy: 0.5160 - lr: 3.1623e-04
# Epoch 27/100
# 500/500 [==============================] - ETA: 0s - loss: 0.6896 - accuracy: 0.5329
# Epoch 27: val_accuracy did not improve from 0.52400
# 500/500 [==============================] - 31s 61ms/step - loss: 0.6896 - accuracy: 0.5329 - val_loss: 0.6956 - val_accuracy: 0.5110 - lr: 3.1623e-04
# Epoch 28/100
# 500/500 [==============================] - ETA: 0s - loss: 0.6887 - accuracy: 0.5312
# Epoch 28: val_accuracy did not improve from 0.52400
# 500/500 [==============================] - 30s 60ms/step - loss: 0.6887 - accuracy: 0.5312 - val_loss: 0.6961 - val_accuracy: 0.5130 - lr: 3.1623e-04
# Epoch 29/100
# 500/500 [==============================] - ETA: 0s - loss: 0.6885 - accuracy: 0.5346
# Epoch 29: val_accuracy did not improve from 0.52400
# 500/500 [==============================] - 30s 60ms/step - loss: 0.6885 - accuracy: 0.5346 - val_loss: 0.6964 - val_accuracy: 0.5120 - lr: 3.1623e-04
# Epoch 30/100
# 500/500 [==============================] - ETA: 0s - loss: 0.6880 - accuracy: 0.5353
# Epoch 30: val_accuracy did not improve from 0.52400
# 500/500 [==============================] - 30s 60ms/step - loss: 0.6880 - accuracy: 0.5353 - val_loss: 0.6968 - val_accuracy: 0.5140 - lr: 3.1623e-04
# Epoch 31/100
# 500/500 [==============================] - ETA: 0s - loss: 0.6877 - accuracy: 0.5372
# Epoch 31: val_accuracy did not improve from 0.52400
# 500/500 [==============================] - 30s 61ms/step - loss: 0.6877 - accuracy: 0.5372 - val_loss: 0.6972 - val_accuracy: 0.5090 - lr: 3.1623e-04
# Epoch 32/100
# 500/500 [==============================] - ETA: 0s - loss: 0.6868 - accuracy: 0.5395
# Epoch 32: val_accuracy did not improve from 0.52400
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.00010000000639606199.
# 500/500 [==============================] - 31s 61ms/step - loss: 0.6868 - accuracy: 0.5395 - val_loss: 0.6969 - val_accuracy: 0.5090 - lr: 3.1623e-04
# Epoch 33/100
# 500/500 [==============================] - ETA: 0s - loss: 0.6833 - accuracy: 0.5504
# Epoch 33: val_accuracy did not improve from 0.52400
# 500/500 [==============================] - 30s 60ms/step - loss: 0.6833 - accuracy: 0.5504 - val_loss: 0.6959 - val_accuracy: 0.5110 - lr: 1.0000e-04
# Epoch 34/100
# 500/500 [==============================] - ETA: 0s - loss: 0.6819 - accuracy: 0.5500
# Epoch 34: val_accuracy did not improve from 0.52400
# 500/500 [==============================] - 30s 60ms/step - loss: 0.6819 - accuracy: 0.5500 - val_loss: 0.6973 - val_accuracy: 0.5120 - lr: 1.0000e-04
# Epoch 35/100
# 500/500 [==============================] - ETA: 0s - loss: 0.6807 - accuracy: 0.5564
# Epoch 35: val_accuracy did not improve from 0.52400
# 500/500 [==============================] - 31s 61ms/step - loss: 0.6807 - accuracy: 0.5564 - val_loss: 0.6993 - val_accuracy: 0.5180 - lr: 1.0000e-04
# Epoch 36/100
# 500/500 [==============================] - ETA: 0s - loss: 0.6806 - accuracy: 0.5554
# Epoch 36: val_accuracy did not improve from 0.52400
# 500/500 [==============================] - 30s 61ms/step - loss: 0.6806 - accuracy: 0.5554 - val_loss: 0.7005 - val_accuracy: 0.5150 - lr: 1.0000e-04
# Epoch 37/100
# 500/500 [==============================] - ETA: 0s - loss: 0.6796 - accuracy: 0.5555
# Epoch 37: val_accuracy did not improve from 0.52400
# 500/500 [==============================] - 30s 60ms/step - loss: 0.6796 - accuracy: 0.5555 - val_loss: 0.7019 - val_accuracy: 0.5060 - lr: 1.0000e-04
# Epoch 38/100
# 500/500 [==============================] - ETA: 0s - loss: 0.6784 - accuracy: 0.5610
# Epoch 38: val_accuracy did not improve from 0.52400
# 500/500 [==============================] - 30s 60ms/step - loss: 0.6784 - accuracy: 0.5610 - val_loss: 0.7024 - val_accuracy: 0.5070 - lr: 1.0000e-04
# Epoch 39/100
# 500/500 [==============================] - ETA: 0s - loss: 0.6780 - accuracy: 0.5609
# Epoch 39: val_accuracy did not improve from 0.52400
# 500/500 [==============================] - 31s 61ms/step - loss: 0.6780 - accuracy: 0.5609 - val_loss: 0.7039 - val_accuracy: 0.5010 - lr: 1.0000e-04
# Epoch 40/100
# 500/500 [==============================] - ETA: 0s - loss: 0.6769 - accuracy: 0.5620
# Epoch 40: val_accuracy did not improve from 0.52400
# 500/500 [==============================] - 31s 61ms/step - loss: 0.6769 - accuracy: 0.5620 - val_loss: 0.7058 - val_accuracy: 0.5030 - lr: 1.0000e-04
# Epoch 41/100
# 500/500 [==============================] - ETA: 0s - loss: 0.6758 - accuracy: 0.5633
# Epoch 41: val_accuracy did not improve from 0.52400
# 500/500 [==============================] - 30s 60ms/step - loss: 0.6758 - accuracy: 0.5633 - val_loss: 0.7080 - val_accuracy: 0.4990 - lr: 1.0000e-04
# Epoch 42/100
# 500/500 [==============================] - ETA: 0s - loss: 0.6744 - accuracy: 0.5674
# Epoch 42: val_accuracy did not improve from 0.52400
# 500/500 [==============================] - 30s 60ms/step - loss: 0.6744 - accuracy: 0.5674 - val_loss: 0.7102 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 42: early stopping

# %%
model.load_weights(model_path)
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'])
plt.show()
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'])
plt.show()

# %%
from tensorflow.keras.models import load_model
model = load_model(model_path)
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %%
test_ds = tf.data.Dataset.list_files(str(test_dir/'*/*'), shuffle=False)
test_ds = test_ds.shuffle(len(test_ds), reshuffle_each_iteration=False)
test_ds = test_ds.map(load, num_parallel_calls=tf.data.AUTOTUNE)
test_ds = test_ds.cache()
test_ds = test_ds.batch(batch_size)
test_ds_length = len(test_ds)

print(f'test_ds_length: {test_ds_length}')
# Out:
# test_ds_length: 63

# %%
model.evaluate(test_ds)
# Out:
# 63/63 [==============================] - 4s 57ms/step - loss: 0.7933 - accuracy: 0.5970
# [0.7933207750320435, 0.597000002861023]
