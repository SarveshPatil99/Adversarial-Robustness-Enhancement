# %% [markdown]
# <a href="https://colab.research.google.com/github/SarveshPatil99/Adversarial-Robustness-Enhancement/blob/main/TML_Dataset_Curation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Directory Structure Creation for All Datasets

# %%
import os

def create_dataset_structure(base_path='original'):
    categories = ['train', 'val', 'test']
    types = ['real', 'fake']

    for category in categories:
        for image_type in types:
            # Construct the path to the directory
            dir_path = os.path.join(base_path, category, image_type)
            # Create the directory with nested structure
            # exist_ok=True is used to avoid error if the directory already exists
            os.makedirs(dir_path, exist_ok=True)
            print(f"Directory created: {dir_path}")

if __name__ == "__main__":
    create_dataset_structure()
# Out:
# Directory created: original/train/real
# Directory created: original/train/fake
# Directory created: original/val/real
# Directory created: original/val/fake
# Directory created: original/test/real
# Directory created: original/test/fake

# %%
import os

def create_noise_dataset_structure(base_paths):
    categories = ['train', 'val', 'test']
    types = ['real', 'fake']

    for base_path in base_paths:
        for category in categories:
            for image_type in types:
                # Construct the path to the directory
                dir_path = os.path.join(base_path, category, image_type)
                # Create the directory with nested structure
                # exist_ok=True is used to avoid error if the directory already exists
                os.makedirs(dir_path, exist_ok=True)
                print(f"Directory created: {dir_path}")

if __name__ == "__main__":
    noises = ['gaussian', 'uniform', 'salt_and_pepper', 'speckle']
    # Create a separate root folder for each type of noise
    base_paths = [f'noise_{noise}' for noise in noises]
    create_noise_dataset_structure(base_paths)
# Out:
# Directory created: noise_gaussian/train/real
# Directory created: noise_gaussian/train/fake
# Directory created: noise_gaussian/val/real
# Directory created: noise_gaussian/val/fake
# Directory created: noise_gaussian/test/real
# Directory created: noise_gaussian/test/fake
# Directory created: noise_uniform/train/real
# Directory created: noise_uniform/train/fake
# Directory created: noise_uniform/val/real
# Directory created: noise_uniform/val/fake
# Directory created: noise_uniform/test/real
# Directory created: noise_uniform/test/fake
# Directory created: noise_salt_and_pepper/train/real
# Directory created: noise_salt_and_pepper/train/fake
# Directory created: noise_salt_and_pepper/val/real
# Directory created: noise_salt_and_pepper/val/fake
# Directory created: noise_salt_and_pepper/test/real
# Directory created: noise_salt_and_pepper/test/fake
# Directory created: noise_speckle/train/real
# Directory created: noise_speckle/train/fake
# Directory created: noise_speckle/val/real
# Directory created: noise_speckle/val/fake
# Directory created: noise_speckle/test/real
# Directory created: noise_speckle/test/fake

# %%
import os

def create_mixed_dataset_structure(base_path, ratios):
    categories = ['train', 'val']
    types = ['real', 'fake']

    for ratio in ratios:
            # Construct the base path including the noise ratio
            ratio_path = f"{base_path}_{ratio}"
            for category in categories:
                for image_type in types:
                    # Construct the path to the directory
                    dir_path = os.path.join(ratio_path, category, image_type)
                    # Create the directory with nested structure
                    # exist_ok=True is used to avoid error if the directory already exists
                    os.makedirs(dir_path, exist_ok=True)
                    print(f"Directory created: {dir_path}")

if __name__ == "__main__":
    # Names of the noises will be determined after Phase II, but we prepare for all possibilities.
    noises = ['']
    # Ratios of original to noisy data
    ratios = ['1_1', '1_2', '2_1']

    # Create a base path for mixed datasets
    base_path = 'mixed_noise'
    create_mixed_dataset_structure(base_path, ratios)
# Out:
# Directory created: mixed_noise_1_1/train/real
# Directory created: mixed_noise_1_1/train/fake
# Directory created: mixed_noise_1_1/val/real
# Directory created: mixed_noise_1_1/val/fake
# Directory created: mixed_noise_1_2/train/real
# Directory created: mixed_noise_1_2/train/fake
# Directory created: mixed_noise_1_2/val/real
# Directory created: mixed_noise_1_2/val/fake
# Directory created: mixed_noise_2_1/train/real
# Directory created: mixed_noise_2_1/train/fake
# Directory created: mixed_noise_2_1/val/real
# Directory created: mixed_noise_2_1/val/fake

# %%
import os

# Define the adversarial attack types
adversarial_attacks = ['fgsm', 'bim', 'pgd']

# Directory structure for the test phase
dir_structure = {
    'test': ['real', 'fake']
}

# Create base directories for each adversarial attack type
for attack in adversarial_attacks:
    # Create a base directory for the current attack (e.g., 'fgsm_test')
    base_attack_dir = f'adversarial_{attack}'

    for phase in dir_structure:
        # Create a sub-directory for test (e.g., 'fgsm_test/test')
        phase_dir = os.path.join(base_attack_dir, phase)

        for category in dir_structure[phase]:
            # Create sub-directories for real and fake categories (e.g., 'fgsm_test/test/real')
            category_dir = os.path.join(phase_dir, category)
            os.makedirs(category_dir, exist_ok=True)
            print(f"Created directory: {category_dir}")
# Out:
# Created directory: adversarial_fgsm/test/real
# Created directory: adversarial_fgsm/test/fake
# Created directory: adversarial_bim/test/real
# Created directory: adversarial_bim/test/fake
# Created directory: adversarial_pgd/test/real
# Created directory: adversarial_pgd/test/fake

# %% [markdown]
# ### Real Dataset Curation

# %%
# !rm -r ~/.kaggle
# !mkdir ~/.kaggle
# !cp ./kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# rm: cannot remove '/root/.kaggle': No such file or directory

# %%
# !kaggle datasets download -d denislukovnikov/ffhq256-images-only
# Out:
# Downloading ffhq256-images-only.zip to /content
# 100% 6.89G/6.91G [01:06<00:00, 131MB/s]
# 100% 6.91G/6.91G [01:06<00:00, 112MB/s]

# %%
# !unzip ffhq256-images-only.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: ffhq256/65000.png
#   inflating: ffhq256/65001.png
#   inflating: ffhq256/65002.png
#   inflating: ffhq256/65003.png
#   inflating: ffhq256/65004.png
#   inflating: ffhq256/65005.png
#   inflating: ffhq256/65006.png
#   inflating: ffhq256/65007.png
#   inflating: ffhq256/65008.png
#   inflating: ffhq256/65009.png
#   inflating: ffhq256/65010.png
#   inflating: ffhq256/65011.png
#   inflating: ffhq256/65012.png
#   inflating: ffhq256/65013.png
#   inflating: ffhq256/65014.png
#   inflating: ffhq256/65015.png
#   inflating: ffhq256/65016.png
#   inflating: ffhq256/65017.png
#   inflating: ffhq256/65018.png
#   inflating: ffhq256/65019.png
#   inflating: ffhq256/65020.png
#   inflating: ffhq256/65021.png
#   inflating: ffhq256/65022.png
#   inflating: ffhq256/65023.png
#   inflating: ffhq256/65024.png
#   inflating: ffhq256/65025.png
#   inflating: ffhq256/65026.png
#   inflating: ffhq256/65027.png
#   inflating: ffhq256/65028.png
#   inflating: ffhq256/65029.png
#   inflating: ffhq256/65030.png
#   inflating: ffhq256/65031.png
#   inflating: ffhq256/65032.png
#   inflating: ffhq256/65033.png
#   inflating: ffhq256/65034.png
#   inflating: ffhq256/69973.png
#   inflating: ffhq256/69974.png
#   inflating: ffhq256/69975.png
#   inflating: ffhq256/69976.png
#   inflating: ffhq256/69977.png
#   inflating: ffhq256/69978.png
#   inflating: ffhq256/69979.png
#   inflating: ffhq256/69980.png
#   inflating: ffhq256/69981.png
#   inflating: ffhq256/69982.png
#   inflating: ffhq256/69983.png
#   inflating: ffhq256/69984.png
#   inflating: ffhq256/69985.png
#   inflating: ffhq256/69986.png
#   inflating: ffhq256/69987.png
#   inflating: ffhq256/69988.png
#   inflating: ffhq256/69989.png
#   inflating: ffhq256/69990.png
#   inflating: ffhq256/69991.png
#   inflating: ffhq256/69992.png
#   inflating: ffhq256/69993.png
#   inflating: ffhq256/69994.png
#   inflating: ffhq256/69995.png
#   inflating: ffhq256/69996.png
#   inflating: ffhq256/69997.png
#   inflating: ffhq256/69998.png
#   inflating: ffhq256/69999.png

# %%
import os
import shutil

# Define the source and destination directories
source_dir = 'ffhq256'
destination_dir = 'real_images_directory'

# Create the destination directory if it doesn't already exist
os.makedirs(destination_dir, exist_ok=True)

# Iterate over the first 5,000 images and move them to the destination
for i in range(5000):
    # Format the filename with leading zeros
    file_name = f"{i:05d}.png"
    # Define the source and destination file paths
    source_file = os.path.join(source_dir, file_name)
    destination_file = os.path.join(destination_dir, file_name)

    # Move the file
    shutil.move(source_file, destination_file)

print(f"First 5,000 images moved to {destination_dir}.")
# Out:
# First 5,000 images moved to real_images_directory.

# %%
import os
import shutil

# Define the base path for the 'original' directory
base_original_dir = 'original'

# Define the directories for train, validation, and test sets
train_dir = os.path.join(base_original_dir, 'train', 'real')
val_dir = os.path.join(base_original_dir, 'val', 'real')
test_dir = os.path.join(base_original_dir, 'test', 'real')

# Create the directories if they don't exist
os.makedirs(train_dir, exist_ok=True)
os.makedirs(val_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

# Source directory containing all real images
source_dir = 'real_images_directory'

# Move the first 8000 images to the train directory
for i in range(4000):
    file_name = f"{i:05d}.png"
    source_file = os.path.join(source_dir, file_name)
    destination_file = os.path.join(train_dir, file_name)
    shutil.move(source_file, destination_file)

# Move the next 1000 images to the validation directory
for i in range(4000, 4500):
    file_name = f"{i:05d}.png"
    source_file = os.path.join(source_dir, file_name)
    destination_file = os.path.join(val_dir, file_name)
    shutil.move(source_file, destination_file)

# Move the last 1000 images to the test directory
for i in range(4500, 5000):
    file_name = f"{i:05d}.png"
    source_file = os.path.join(source_dir, file_name)
    destination_file = os.path.join(test_dir, file_name)
    shutil.move(source_file, destination_file)

print("Images distributed to train, val, and test directories.")
# Out:
# Images distributed to train, val, and test directories.

# %%
import os

def count_images_in_directory(directory):
    # Initialize a counter
    count = 0
    # Walk through all files and directories within the given directory
    for root, dirs, files in os.walk(directory):
        # Count the number of PNG files
        count += len([file for file in files if file.endswith('.png')])
        print(f"There are {count} images in '{root}' directory.")
        # Reset the counter after printing out the count for the current directory
        count = 0

# Define the base path for the 'original' directory
base_original_dir = 'original'

# Call the function with the path to the 'original' directory
count_images_in_directory(base_original_dir)
# Out:
# There are 0 images in 'original' directory.
# There are 0 images in 'original/test' directory.
# There are 0 images in 'original/test/fake' directory.
# There are 500 images in 'original/test/real' directory.
# There are 0 images in 'original/train' directory.
# There are 0 images in 'original/train/fake' directory.
# There are 4000 images in 'original/train/real' directory.
# There are 0 images in 'original/val' directory.
# There are 0 images in 'original/val/fake' directory.
# There are 500 images in 'original/val/real' directory.

# %% [markdown]
# ### Fake Dataset Curation

# %%
# !git clone https://github.com/NVlabs/stylegan3.git
# Out:
# Cloning into 'stylegan3'...
# remote: Enumerating objects: 212, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 212 (delta 0), reused 1 (delta 0), pack-reused 207
# Receiving objects: 100% (212/212), 4.17 MiB | 18.19 MiB/s, done.
# Resolving deltas: 100% (98/98), done.

# %%
import os
os.chdir('stylegan3/')

# %%
# !sudo apt-get install ninja-build
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   ninja-build
# 0 upgraded, 1 newly installed, 0 to remove and 19 not upgraded.
# Need to get 111 kB of archives.
# After this operation, 358 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 ninja-build amd64 1.10.1-1 [111 kB]
# Fetched 111 kB in 1s (182 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package ninja-build.
# (Reading database ... 120874 files and directories currently installed.)
# Preparing to unpack .../ninja-build_1.10.1-1_amd64.deb ...
# Unpacking ninja-build (1.10.1-1) ...
# Setting up ninja-build (1.10.1-1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# Generate an image using pre-trained AFHQv2 model ("Ours" in Figure 1, left).
# stylegan3-t-ffhq-1024x1024.pkl
#stylegan3-r-ffhq-1024x1024.pkl
# !python gen_images.py --outdir=out --seeds=0-4999 \
    --network=https://api.ngc.nvidia.com/v2/models/nvidia/research/stylegan3/versions/1/files/stylegan3-r-ffhq-1024x1024.pkl
# Out:
# Streaming output truncated to the last 5000 lines.
# Setting up PyTorch plugin "filtered_lrelu_plugin"... Done.
# Generating image for seed 1 (1/5000) ...
# Generating image for seed 2 (2/5000) ...
# Generating image for seed 3 (3/5000) ...
# Generating image for seed 4 (4/5000) ...
# Generating image for seed 5 (5/5000) ...
# Generating image for seed 6 (6/5000) ...
# Generating image for seed 7 (7/5000) ...
# Generating image for seed 8 (8/5000) ...
# Generating image for seed 9 (9/5000) ...
# Generating image for seed 10 (10/5000) ...
# Generating image for seed 11 (11/5000) ...
# Generating image for seed 12 (12/5000) ...
# Generating image for seed 13 (13/5000) ...
# Generating image for seed 14 (14/5000) ...
# Generating image for seed 15 (15/5000) ...
# Generating image for seed 16 (16/5000) ...
# Generating image for seed 17 (17/5000) ...
# Generating image for seed 18 (18/5000) ...
# Generating image for seed 19 (19/5000) ...
# Generating image for seed 20 (20/5000) ...
# Generating image for seed 21 (21/5000) ...
# Generating image for seed 22 (22/5000) ...
# Generating image for seed 23 (23/5000) ...
# Generating image for seed 24 (24/5000) ...
# Generating image for seed 25 (25/5000) ...
# Generating image for seed 26 (26/5000) ...
# Generating image for seed 27 (27/5000) ...
# Generating image for seed 28 (28/5000) ...
# Generating image for seed 29 (29/5000) ...
# Generating image for seed 30 (30/5000) ...
# Generating image for seed 31 (31/5000) ...
# Generating image for seed 32 (32/5000) ...
# Generating image for seed 33 (33/5000) ...
# Generating image for seed 34 (34/5000) ...
# Generating image for seed 35 (35/5000) ...
# Generating image for seed 36 (36/5000) ...
# Generating image for seed 37 (37/5000) ...
# Generating image for seed 38 (38/5000) ...
# Generating image for seed 39 (39/5000) ...
# Generating image for seed 40 (40/5000) ...
# Generating image for seed 41 (41/5000) ...
# Generating image for seed 42 (42/5000) ...
# Generating image for seed 43 (43/5000) ...
# Generating image for seed 44 (44/5000) ...
# Generating image for seed 45 (45/5000) ...
# Generating image for seed 46 (46/5000) ...
# Generating image for seed 47 (47/5000) ...
# Generating image for seed 48 (48/5000) ...
# Generating image for seed 49 (49/5000) ...
# Generating image for seed 50 (50/5000) ...
# Generating image for seed 51 (51/5000) ...
# Generating image for seed 52 (52/5000) ...
# Generating image for seed 53 (53/5000) ...
# Generating image for seed 54 (54/5000) ...
# Generating image for seed 55 (55/5000) ...
# Generating image for seed 56 (56/5000) ...
# Generating image for seed 57 (57/5000) ...
# Generating image for seed 58 (58/5000) ...
# Generating image for seed 59 (59/5000) ...
# Generating image for seed 60 (60/5000) ...
# Generating image for seed 61 (61/5000) ...
# Generating image for seed 62 (62/5000) ...
# Generating image for seed 63 (63/5000) ...
# Generating image for seed 64 (64/5000) ...
# Generating image for seed 65 (65/5000) ...
# Generating image for seed 66 (66/5000) ...
# Generating image for seed 67 (67/5000) ...
# Generating image for seed 68 (68/5000) ...
# Generating image for seed 69 (69/5000) ...
# Generating image for seed 70 (70/5000) ...
# Generating image for seed 71 (71/5000) ...
# Generating image for seed 72 (72/5000) ...
# Generating image for seed 73 (73/5000) ...
# Generating image for seed 74 (74/5000) ...
# Generating image for seed 75 (75/5000) ...
# Generating image for seed 76 (76/5000) ...
# Generating image for seed 77 (77/5000) ...
# Generating image for seed 78 (78/5000) ...
# Generating image for seed 79 (79/5000) ...
# Generating image for seed 80 (80/5000) ...
# Generating image for seed 81 (81/5000) ...
# Generating image for seed 82 (82/5000) ...
# Generating image for seed 83 (83/5000) ...
# Generating image for seed 84 (84/5000) ...
# Generating image for seed 85 (85/5000) ...
# Generating image for seed 86 (86/5000) ...
# Generating image for seed 87 (87/5000) ...
# Generating image for seed 88 (88/5000) ...
# Generating image for seed 89 (89/5000) ...
# Generating image for seed 90 (90/5000) ...
# Generating image for seed 91 (91/5000) ...
# Generating image for seed 92 (92/5000) ...
# Generating image for seed 93 (93/5000) ...
# Generating image for seed 94 (94/5000) ...
# Generating image for seed 95 (95/5000) ...
# Generating image for seed 96 (96/5000) ...
# Generating image for seed 97 (97/5000) ...
# Generating image for seed 98 (98/5000) ...
# Generating image for seed 99 (99/5000) ...
# Generating image for seed 100 (100/5000) ...
# Generating image for seed 101 (101/5000) ...
# Generating image for seed 102 (102/5000) ...
# Generating image for seed 103 (103/5000) ...
# Generating image for seed 104 (104/5000) ...
# Generating image for seed 105 (105/5000) ...
# Generating image for seed 106 (106/5000) ...
# Generating image for seed 107 (107/5000) ...
# Generating image for seed 108 (108/5000) ...
# Generating image for seed 109 (109/5000) ...
# Generating image for seed 110 (110/5000) ...
# Generating image for seed 111 (111/5000) ...
# Generating image for seed 112 (112/5000) ...
# Generating image for seed 113 (113/5000) ...
# Generating image for seed 114 (114/5000) ...
# Generating image for seed 115 (115/5000) ...
# Generating image for seed 116 (116/5000) ...
# Generating image for seed 117 (117/5000) ...
# Generating image for seed 118 (118/5000) ...
# Generating image for seed 119 (119/5000) ...
# Generating image for seed 120 (120/5000) ...
# Generating image for seed 121 (121/5000) ...
# Generating image for seed 122 (122/5000) ...
# Generating image for seed 123 (123/5000) ...
# Generating image for seed 124 (124/5000) ...
# Generating image for seed 125 (125/5000) ...
# Generating image for seed 126 (126/5000) ...
# Generating image for seed 127 (127/5000) ...
# Generating image for seed 128 (128/5000) ...
# Generating image for seed 129 (129/5000) ...
# Generating image for seed 130 (130/5000) ...
# Generating image for seed 131 (131/5000) ...
# Generating image for seed 132 (132/5000) ...
# Generating image for seed 133 (133/5000) ...
# Generating image for seed 134 (134/5000) ...
# Generating image for seed 135 (135/5000) ...
# Generating image for seed 136 (136/5000) ...
# Generating image for seed 137 (137/5000) ...
# Generating image for seed 138 (138/5000) ...
# Generating image for seed 139 (139/5000) ...
# Generating image for seed 140 (140/5000) ...
# Generating image for seed 141 (141/5000) ...
# Generating image for seed 142 (142/5000) ...
# Generating image for seed 143 (143/5000) ...
# Generating image for seed 144 (144/5000) ...
# Generating image for seed 145 (145/5000) ...
# Generating image for seed 146 (146/5000) ...
# Generating image for seed 147 (147/5000) ...
# Generating image for seed 148 (148/5000) ...
# Generating image for seed 149 (149/5000) ...
# Generating image for seed 150 (150/5000) ...
# Generating image for seed 151 (151/5000) ...
# Generating image for seed 152 (152/5000) ...
# Generating image for seed 153 (153/5000) ...
# Generating image for seed 154 (154/5000) ...
# Generating image for seed 155 (155/5000) ...
# Generating image for seed 156 (156/5000) ...
# Generating image for seed 157 (157/5000) ...
# Generating image for seed 158 (158/5000) ...
# Generating image for seed 159 (159/5000) ...
# Generating image for seed 160 (160/5000) ...
# Generating image for seed 161 (161/5000) ...
# Generating image for seed 162 (162/5000) ...
# Generating image for seed 163 (163/5000) ...
# Generating image for seed 164 (164/5000) ...
# Generating image for seed 165 (165/5000) ...
# Generating image for seed 166 (166/5000) ...
# Generating image for seed 167 (167/5000) ...
# Generating image for seed 168 (168/5000) ...
# Generating image for seed 169 (169/5000) ...
# Generating image for seed 170 (170/5000) ...
# Generating image for seed 171 (171/5000) ...
# Generating image for seed 172 (172/5000) ...
# Generating image for seed 173 (173/5000) ...
# Generating image for seed 174 (174/5000) ...
# Generating image for seed 175 (175/5000) ...
# Generating image for seed 176 (176/5000) ...
# Generating image for seed 177 (177/5000) ...
# Generating image for seed 178 (178/5000) ...
# Generating image for seed 179 (179/5000) ...
# Generating image for seed 180 (180/5000) ...
# Generating image for seed 181 (181/5000) ...
# Generating image for seed 182 (182/5000) ...
# Generating image for seed 183 (183/5000) ...
# Generating image for seed 184 (184/5000) ...
# Generating image for seed 185 (185/5000) ...
# Generating image for seed 186 (186/5000) ...
# Generating image for seed 187 (187/5000) ...
# Generating image for seed 188 (188/5000) ...
# Generating image for seed 189 (189/5000) ...
# Generating image for seed 190 (190/5000) ...
# Generating image for seed 191 (191/5000) ...
# Generating image for seed 192 (192/5000) ...
# Generating image for seed 193 (193/5000) ...
# Generating image for seed 194 (194/5000) ...
# Generating image for seed 195 (195/5000) ...
# Generating image for seed 196 (196/5000) ...
# Generating image for seed 197 (197/5000) ...
# Generating image for seed 198 (198/5000) ...
# Generating image for seed 199 (199/5000) ...
# Generating image for seed 200 (200/5000) ...
# Generating image for seed 201 (201/5000) ...
# Generating image for seed 202 (202/5000) ...
# Generating image for seed 203 (203/5000) ...
# Generating image for seed 204 (204/5000) ...
# Generating image for seed 205 (205/5000) ...
# Generating image for seed 206 (206/5000) ...
# Generating image for seed 207 (207/5000) ...
# Generating image for seed 208 (208/5000) ...
# Generating image for seed 209 (209/5000) ...
# Generating image for seed 210 (210/5000) ...
# Generating image for seed 211 (211/5000) ...
# Generating image for seed 212 (212/5000) ...
# Generating image for seed 213 (213/5000) ...
# Generating image for seed 214 (214/5000) ...
# Generating image for seed 215 (215/5000) ...
# Generating image for seed 216 (216/5000) ...
# Generating image for seed 217 (217/5000) ...
# Generating image for seed 218 (218/5000) ...
# Generating image for seed 219 (219/5000) ...
# Generating image for seed 220 (220/5000) ...
# Generating image for seed 221 (221/5000) ...
# Generating image for seed 222 (222/5000) ...
# Generating image for seed 223 (223/5000) ...
# Generating image for seed 224 (224/5000) ...
# Generating image for seed 225 (225/5000) ...
# Generating image for seed 226 (226/5000) ...
# Generating image for seed 227 (227/5000) ...
# Generating image for seed 228 (228/5000) ...
# Generating image for seed 229 (229/5000) ...
# Generating image for seed 230 (230/5000) ...
# Generating image for seed 231 (231/5000) ...
# Generating image for seed 232 (232/5000) ...
# Generating image for seed 233 (233/5000) ...
# Generating image for seed 234 (234/5000) ...
# Generating image for seed 235 (235/5000) ...
# Generating image for seed 236 (236/5000) ...
# Generating image for seed 237 (237/5000) ...
# Generating image for seed 238 (238/5000) ...
# Generating image for seed 239 (239/5000) ...
# Generating image for seed 240 (240/5000) ...
# Generating image for seed 241 (241/5000) ...
# Generating image for seed 242 (242/5000) ...
# Generating image for seed 243 (243/5000) ...
# Generating image for seed 244 (244/5000) ...
# Generating image for seed 245 (245/5000) ...
# Generating image for seed 246 (246/5000) ...
# Generating image for seed 247 (247/5000) ...
# Generating image for seed 248 (248/5000) ...
# Generating image for seed 249 (249/5000) ...
# Generating image for seed 250 (250/5000) ...
# Generating image for seed 251 (251/5000) ...
# Generating image for seed 252 (252/5000) ...
# Generating image for seed 253 (253/5000) ...
# Generating image for seed 254 (254/5000) ...
# Generating image for seed 255 (255/5000) ...
# Generating image for seed 256 (256/5000) ...
# Generating image for seed 257 (257/5000) ...
# Generating image for seed 258 (258/5000) ...
# Generating image for seed 259 (259/5000) ...
# Generating image for seed 260 (260/5000) ...
# Generating image for seed 261 (261/5000) ...
# Generating image for seed 262 (262/5000) ...
# Generating image for seed 263 (263/5000) ...
# Generating image for seed 264 (264/5000) ...
# Generating image for seed 265 (265/5000) ...
# Generating image for seed 266 (266/5000) ...
# Generating image for seed 267 (267/5000) ...
# Generating image for seed 268 (268/5000) ...
# Generating image for seed 269 (269/5000) ...
# Generating image for seed 270 (270/5000) ...
# Generating image for seed 271 (271/5000) ...
# Generating image for seed 272 (272/5000) ...
# Generating image for seed 273 (273/5000) ...
# Generating image for seed 274 (274/5000) ...
# Generating image for seed 275 (275/5000) ...
# Generating image for seed 276 (276/5000) ...
# Generating image for seed 277 (277/5000) ...
# Generating image for seed 278 (278/5000) ...
# Generating image for seed 279 (279/5000) ...
# Generating image for seed 280 (280/5000) ...
# Generating image for seed 281 (281/5000) ...
# Generating image for seed 282 (282/5000) ...
# Generating image for seed 283 (283/5000) ...
# Generating image for seed 284 (284/5000) ...
# Generating image for seed 285 (285/5000) ...
# Generating image for seed 286 (286/5000) ...
# Generating image for seed 287 (287/5000) ...
# Generating image for seed 288 (288/5000) ...
# Generating image for seed 289 (289/5000) ...
# Generating image for seed 290 (290/5000) ...
# Generating image for seed 291 (291/5000) ...
# Generating image for seed 292 (292/5000) ...
# Generating image for seed 293 (293/5000) ...
# Generating image for seed 294 (294/5000) ...
# Generating image for seed 295 (295/5000) ...
# Generating image for seed 296 (296/5000) ...
# Generating image for seed 297 (297/5000) ...
# Generating image for seed 298 (298/5000) ...
# Generating image for seed 299 (299/5000) ...
# Generating image for seed 300 (300/5000) ...
# Generating image for seed 301 (301/5000) ...
# Generating image for seed 302 (302/5000) ...
# Generating image for seed 303 (303/5000) ...
# Generating image for seed 304 (304/5000) ...
# Generating image for seed 305 (305/5000) ...
# Generating image for seed 306 (306/5000) ...
# Generating image for seed 307 (307/5000) ...
# Generating image for seed 308 (308/5000) ...
# Generating image for seed 309 (309/5000) ...
# Generating image for seed 310 (310/5000) ...
# Generating image for seed 311 (311/5000) ...
# Generating image for seed 312 (312/5000) ...
# Generating image for seed 313 (313/5000) ...
# Generating image for seed 314 (314/5000) ...
# Generating image for seed 315 (315/5000) ...
# Generating image for seed 316 (316/5000) ...
# Generating image for seed 317 (317/5000) ...
# Generating image for seed 318 (318/5000) ...
# Generating image for seed 319 (319/5000) ...
# Generating image for seed 320 (320/5000) ...
# Generating image for seed 321 (321/5000) ...
# Generating image for seed 322 (322/5000) ...
# Generating image for seed 323 (323/5000) ...
# Generating image for seed 324 (324/5000) ...
# Generating image for seed 325 (325/5000) ...
# Generating image for seed 326 (326/5000) ...
# Generating image for seed 327 (327/5000) ...
# Generating image for seed 328 (328/5000) ...
# Generating image for seed 329 (329/5000) ...
# Generating image for seed 330 (330/5000) ...
# Generating image for seed 331 (331/5000) ...
# Generating image for seed 332 (332/5000) ...
# Generating image for seed 333 (333/5000) ...
# Generating image for seed 334 (334/5000) ...
# Generating image for seed 335 (335/5000) ...
# Generating image for seed 336 (336/5000) ...
# Generating image for seed 337 (337/5000) ...
# Generating image for seed 338 (338/5000) ...
# Generating image for seed 339 (339/5000) ...
# Generating image for seed 340 (340/5000) ...
# Generating image for seed 341 (341/5000) ...
# Generating image for seed 342 (342/5000) ...
# Generating image for seed 343 (343/5000) ...
# Generating image for seed 344 (344/5000) ...
# Generating image for seed 345 (345/5000) ...
# Generating image for seed 346 (346/5000) ...
# Generating image for seed 347 (347/5000) ...
# Generating image for seed 348 (348/5000) ...
# Generating image for seed 349 (349/5000) ...
# Generating image for seed 350 (350/5000) ...
# Generating image for seed 351 (351/5000) ...
# Generating image for seed 352 (352/5000) ...
# Generating image for seed 353 (353/5000) ...
# Generating image for seed 354 (354/5000) ...
# Generating image for seed 355 (355/5000) ...
# Generating image for seed 356 (356/5000) ...
# Generating image for seed 357 (357/5000) ...
# Generating image for seed 358 (358/5000) ...
# Generating image for seed 359 (359/5000) ...
# Generating image for seed 360 (360/5000) ...
# Generating image for seed 361 (361/5000) ...
# Generating image for seed 362 (362/5000) ...
# Generating image for seed 363 (363/5000) ...
# Generating image for seed 364 (364/5000) ...
# Generating image for seed 365 (365/5000) ...
# Generating image for seed 366 (366/5000) ...
# Generating image for seed 367 (367/5000) ...
# Generating image for seed 368 (368/5000) ...
# Generating image for seed 369 (369/5000) ...
# Generating image for seed 370 (370/5000) ...
# Generating image for seed 371 (371/5000) ...
# Generating image for seed 372 (372/5000) ...
# Generating image for seed 373 (373/5000) ...
# Generating image for seed 374 (374/5000) ...
# Generating image for seed 375 (375/5000) ...
# Generating image for seed 376 (376/5000) ...
# Generating image for seed 377 (377/5000) ...
# Generating image for seed 378 (378/5000) ...
# Generating image for seed 379 (379/5000) ...
# Generating image for seed 380 (380/5000) ...
# Generating image for seed 381 (381/5000) ...
# Generating image for seed 382 (382/5000) ...
# Generating image for seed 383 (383/5000) ...
# Generating image for seed 384 (384/5000) ...
# Generating image for seed 385 (385/5000) ...
# Generating image for seed 386 (386/5000) ...
# Generating image for seed 387 (387/5000) ...
# Generating image for seed 388 (388/5000) ...
# Generating image for seed 389 (389/5000) ...
# Generating image for seed 390 (390/5000) ...
# Generating image for seed 391 (391/5000) ...
# Generating image for seed 392 (392/5000) ...
# Generating image for seed 393 (393/5000) ...
# Generating image for seed 394 (394/5000) ...
# Generating image for seed 395 (395/5000) ...
# Generating image for seed 396 (396/5000) ...
# Generating image for seed 397 (397/5000) ...
# Generating image for seed 398 (398/5000) ...
# Generating image for seed 399 (399/5000) ...
# Generating image for seed 400 (400/5000) ...
# Generating image for seed 401 (401/5000) ...
# Generating image for seed 402 (402/5000) ...
# Generating image for seed 403 (403/5000) ...
# Generating image for seed 404 (404/5000) ...
# Generating image for seed 405 (405/5000) ...
# Generating image for seed 406 (406/5000) ...
# Generating image for seed 407 (407/5000) ...
# Generating image for seed 408 (408/5000) ...
# Generating image for seed 409 (409/5000) ...
# Generating image for seed 410 (410/5000) ...
# Generating image for seed 411 (411/5000) ...
# Generating image for seed 412 (412/5000) ...
# Generating image for seed 413 (413/5000) ...
# Generating image for seed 414 (414/5000) ...
# Generating image for seed 415 (415/5000) ...
# Generating image for seed 416 (416/5000) ...
# Generating image for seed 417 (417/5000) ...
# Generating image for seed 418 (418/5000) ...
# Generating image for seed 419 (419/5000) ...
# Generating image for seed 420 (420/5000) ...
# Generating image for seed 421 (421/5000) ...
# Generating image for seed 422 (422/5000) ...
# Generating image for seed 423 (423/5000) ...
# Generating image for seed 424 (424/5000) ...
# Generating image for seed 425 (425/5000) ...
# Generating image for seed 426 (426/5000) ...
# Generating image for seed 427 (427/5000) ...
# Generating image for seed 428 (428/5000) ...
# Generating image for seed 429 (429/5000) ...
# Generating image for seed 430 (430/5000) ...
# Generating image for seed 431 (431/5000) ...
# Generating image for seed 432 (432/5000) ...
# Generating image for seed 433 (433/5000) ...
# Generating image for seed 434 (434/5000) ...
# Generating image for seed 435 (435/5000) ...
# Generating image for seed 436 (436/5000) ...
# Generating image for seed 437 (437/5000) ...
# Generating image for seed 438 (438/5000) ...
# Generating image for seed 439 (439/5000) ...
# Generating image for seed 440 (440/5000) ...
# Generating image for seed 441 (441/5000) ...
# Generating image for seed 442 (442/5000) ...
# Generating image for seed 443 (443/5000) ...
# Generating image for seed 444 (444/5000) ...
# Generating image for seed 445 (445/5000) ...
# Generating image for seed 446 (446/5000) ...
# Generating image for seed 447 (447/5000) ...
# Generating image for seed 448 (448/5000) ...
# Generating image for seed 449 (449/5000) ...
# Generating image for seed 450 (450/5000) ...
# Generating image for seed 451 (451/5000) ...
# Generating image for seed 452 (452/5000) ...
# Generating image for seed 453 (453/5000) ...
# Generating image for seed 454 (454/5000) ...
# Generating image for seed 455 (455/5000) ...
# Generating image for seed 456 (456/5000) ...
# Generating image for seed 457 (457/5000) ...
# Generating image for seed 458 (458/5000) ...
# Generating image for seed 459 (459/5000) ...
# Generating image for seed 460 (460/5000) ...
# Generating image for seed 461 (461/5000) ...
# Generating image for seed 462 (462/5000) ...
# Generating image for seed 463 (463/5000) ...
# Generating image for seed 464 (464/5000) ...
# Generating image for seed 465 (465/5000) ...
# Generating image for seed 466 (466/5000) ...
# Generating image for seed 467 (467/5000) ...
# Generating image for seed 468 (468/5000) ...
# Generating image for seed 469 (469/5000) ...
# Generating image for seed 470 (470/5000) ...
# Generating image for seed 471 (471/5000) ...
# Generating image for seed 472 (472/5000) ...
# Generating image for seed 473 (473/5000) ...
# Generating image for seed 474 (474/5000) ...
# Generating image for seed 475 (475/5000) ...
# Generating image for seed 476 (476/5000) ...
# Generating image for seed 477 (477/5000) ...
# Generating image for seed 478 (478/5000) ...
# Generating image for seed 479 (479/5000) ...
# Generating image for seed 480 (480/5000) ...
# Generating image for seed 481 (481/5000) ...
# Generating image for seed 482 (482/5000) ...
# Generating image for seed 483 (483/5000) ...
# Generating image for seed 484 (484/5000) ...
# Generating image for seed 485 (485/5000) ...
# Generating image for seed 486 (486/5000) ...
# Generating image for seed 487 (487/5000) ...
# Generating image for seed 488 (488/5000) ...
# Generating image for seed 489 (489/5000) ...
# Generating image for seed 490 (490/5000) ...
# Generating image for seed 491 (491/5000) ...
# Generating image for seed 492 (492/5000) ...
# Generating image for seed 493 (493/5000) ...
# Generating image for seed 494 (494/5000) ...
# Generating image for seed 495 (495/5000) ...
# Generating image for seed 496 (496/5000) ...
# Generating image for seed 497 (497/5000) ...
# Generating image for seed 498 (498/5000) ...
# Generating image for seed 499 (499/5000) ...
# Generating image for seed 500 (500/5000) ...
# Generating image for seed 501 (501/5000) ...
# Generating image for seed 502 (502/5000) ...
# Generating image for seed 503 (503/5000) ...
# Generating image for seed 504 (504/5000) ...
# Generating image for seed 505 (505/5000) ...
# Generating image for seed 506 (506/5000) ...
# Generating image for seed 507 (507/5000) ...
# Generating image for seed 508 (508/5000) ...
# Generating image for seed 509 (509/5000) ...
# Generating image for seed 510 (510/5000) ...
# Generating image for seed 511 (511/5000) ...
# Generating image for seed 512 (512/5000) ...
# Generating image for seed 513 (513/5000) ...
# Generating image for seed 514 (514/5000) ...
# Generating image for seed 515 (515/5000) ...
# Generating image for seed 516 (516/5000) ...
# Generating image for seed 517 (517/5000) ...
# Generating image for seed 518 (518/5000) ...
# Generating image for seed 519 (519/5000) ...
# Generating image for seed 520 (520/5000) ...
# Generating image for seed 521 (521/5000) ...
# Generating image for seed 522 (522/5000) ...
# Generating image for seed 523 (523/5000) ...
# Generating image for seed 524 (524/5000) ...
# Generating image for seed 525 (525/5000) ...
# Generating image for seed 526 (526/5000) ...
# Generating image for seed 527 (527/5000) ...
# Generating image for seed 528 (528/5000) ...
# Generating image for seed 529 (529/5000) ...
# Generating image for seed 530 (530/5000) ...
# Generating image for seed 531 (531/5000) ...
# Generating image for seed 532 (532/5000) ...
# Generating image for seed 533 (533/5000) ...
# Generating image for seed 534 (534/5000) ...
# Generating image for seed 535 (535/5000) ...
# Generating image for seed 536 (536/5000) ...
# Generating image for seed 537 (537/5000) ...
# Generating image for seed 538 (538/5000) ...
# Generating image for seed 539 (539/5000) ...
# Generating image for seed 540 (540/5000) ...
# Generating image for seed 541 (541/5000) ...
# Generating image for seed 542 (542/5000) ...
# Generating image for seed 543 (543/5000) ...
# Generating image for seed 544 (544/5000) ...
# Generating image for seed 545 (545/5000) ...
# Generating image for seed 546 (546/5000) ...
# Generating image for seed 547 (547/5000) ...
# Generating image for seed 548 (548/5000) ...
# Generating image for seed 549 (549/5000) ...
# Generating image for seed 550 (550/5000) ...
# Generating image for seed 551 (551/5000) ...
# Generating image for seed 552 (552/5000) ...
# Generating image for seed 553 (553/5000) ...
# Generating image for seed 554 (554/5000) ...
# Generating image for seed 555 (555/5000) ...
# Generating image for seed 556 (556/5000) ...
# Generating image for seed 557 (557/5000) ...
# Generating image for seed 558 (558/5000) ...
# Generating image for seed 559 (559/5000) ...
# Generating image for seed 560 (560/5000) ...
# Generating image for seed 561 (561/5000) ...
# Generating image for seed 562 (562/5000) ...
# Generating image for seed 563 (563/5000) ...
# Generating image for seed 564 (564/5000) ...
# Generating image for seed 565 (565/5000) ...
# Generating image for seed 566 (566/5000) ...
# Generating image for seed 567 (567/5000) ...
# Generating image for seed 568 (568/5000) ...
# Generating image for seed 569 (569/5000) ...
# Generating image for seed 570 (570/5000) ...
# Generating image for seed 571 (571/5000) ...
# Generating image for seed 572 (572/5000) ...
# Generating image for seed 573 (573/5000) ...
# Generating image for seed 574 (574/5000) ...
# Generating image for seed 575 (575/5000) ...
# Generating image for seed 576 (576/5000) ...
# Generating image for seed 577 (577/5000) ...
# Generating image for seed 578 (578/5000) ...
# Generating image for seed 579 (579/5000) ...
# Generating image for seed 580 (580/5000) ...
# Generating image for seed 581 (581/5000) ...
# Generating image for seed 582 (582/5000) ...
# Generating image for seed 583 (583/5000) ...
# Generating image for seed 584 (584/5000) ...
# Generating image for seed 585 (585/5000) ...
# Generating image for seed 586 (586/5000) ...
# Generating image for seed 587 (587/5000) ...
# Generating image for seed 588 (588/5000) ...
# Generating image for seed 589 (589/5000) ...
# Generating image for seed 590 (590/5000) ...
# Generating image for seed 591 (591/5000) ...
# Generating image for seed 592 (592/5000) ...
# Generating image for seed 593 (593/5000) ...
# Generating image for seed 594 (594/5000) ...
# Generating image for seed 595 (595/5000) ...
# Generating image for seed 596 (596/5000) ...
# Generating image for seed 597 (597/5000) ...
# Generating image for seed 598 (598/5000) ...
# Generating image for seed 599 (599/5000) ...
# Generating image for seed 600 (600/5000) ...
# Generating image for seed 601 (601/5000) ...
# Generating image for seed 602 (602/5000) ...
# Generating image for seed 603 (603/5000) ...
# Generating image for seed 604 (604/5000) ...
# Generating image for seed 605 (605/5000) ...
# Generating image for seed 606 (606/5000) ...
# Generating image for seed 607 (607/5000) ...
# Generating image for seed 608 (608/5000) ...
# Generating image for seed 609 (609/5000) ...
# Generating image for seed 610 (610/5000) ...
# Generating image for seed 611 (611/5000) ...
# Generating image for seed 612 (612/5000) ...
# Generating image for seed 613 (613/5000) ...
# Generating image for seed 614 (614/5000) ...
# Generating image for seed 615 (615/5000) ...
# Generating image for seed 616 (616/5000) ...
# Generating image for seed 617 (617/5000) ...
# Generating image for seed 618 (618/5000) ...
# Generating image for seed 619 (619/5000) ...
# Generating image for seed 620 (620/5000) ...
# Generating image for seed 621 (621/5000) ...
# Generating image for seed 622 (622/5000) ...
# Generating image for seed 623 (623/5000) ...
# Generating image for seed 624 (624/5000) ...
# Generating image for seed 625 (625/5000) ...
# Generating image for seed 626 (626/5000) ...
# Generating image for seed 627 (627/5000) ...
# Generating image for seed 628 (628/5000) ...
# Generating image for seed 629 (629/5000) ...
# Generating image for seed 630 (630/5000) ...
# Generating image for seed 631 (631/5000) ...
# Generating image for seed 632 (632/5000) ...
# Generating image for seed 633 (633/5000) ...
# Generating image for seed 634 (634/5000) ...
# Generating image for seed 635 (635/5000) ...
# Generating image for seed 636 (636/5000) ...
# Generating image for seed 637 (637/5000) ...
# Generating image for seed 638 (638/5000) ...
# Generating image for seed 639 (639/5000) ...
# Generating image for seed 640 (640/5000) ...
# Generating image for seed 641 (641/5000) ...
# Generating image for seed 642 (642/5000) ...
# Generating image for seed 643 (643/5000) ...
# Generating image for seed 644 (644/5000) ...
# Generating image for seed 645 (645/5000) ...
# Generating image for seed 646 (646/5000) ...
# Generating image for seed 647 (647/5000) ...
# Generating image for seed 648 (648/5000) ...
# Generating image for seed 649 (649/5000) ...
# Generating image for seed 650 (650/5000) ...
# Generating image for seed 651 (651/5000) ...
# Generating image for seed 652 (652/5000) ...
# Generating image for seed 653 (653/5000) ...
# Generating image for seed 654 (654/5000) ...
# Generating image for seed 655 (655/5000) ...
# Generating image for seed 656 (656/5000) ...
# Generating image for seed 657 (657/5000) ...
# Generating image for seed 658 (658/5000) ...
# Generating image for seed 659 (659/5000) ...
# Generating image for seed 660 (660/5000) ...
# Generating image for seed 661 (661/5000) ...
# Generating image for seed 662 (662/5000) ...
# Generating image for seed 663 (663/5000) ...
# Generating image for seed 664 (664/5000) ...
# Generating image for seed 665 (665/5000) ...
# Generating image for seed 666 (666/5000) ...
# Generating image for seed 667 (667/5000) ...
# Generating image for seed 668 (668/5000) ...
# Generating image for seed 669 (669/5000) ...
# Generating image for seed 670 (670/5000) ...
# Generating image for seed 671 (671/5000) ...
# Generating image for seed 672 (672/5000) ...
# Generating image for seed 673 (673/5000) ...
# Generating image for seed 674 (674/5000) ...
# Generating image for seed 675 (675/5000) ...
# Generating image for seed 676 (676/5000) ...
# Generating image for seed 677 (677/5000) ...
# Generating image for seed 678 (678/5000) ...
# Generating image for seed 679 (679/5000) ...
# Generating image for seed 680 (680/5000) ...
# Generating image for seed 681 (681/5000) ...
# Generating image for seed 682 (682/5000) ...
# Generating image for seed 683 (683/5000) ...
# Generating image for seed 684 (684/5000) ...
# Generating image for seed 685 (685/5000) ...
# Generating image for seed 686 (686/5000) ...
# Generating image for seed 687 (687/5000) ...
# Generating image for seed 688 (688/5000) ...
# Generating image for seed 689 (689/5000) ...
# Generating image for seed 690 (690/5000) ...
# Generating image for seed 691 (691/5000) ...
# Generating image for seed 692 (692/5000) ...
# Generating image for seed 693 (693/5000) ...
# Generating image for seed 694 (694/5000) ...
# Generating image for seed 695 (695/5000) ...
# Generating image for seed 696 (696/5000) ...
# Generating image for seed 697 (697/5000) ...
# Generating image for seed 698 (698/5000) ...
# Generating image for seed 699 (699/5000) ...
# Generating image for seed 700 (700/5000) ...
# Generating image for seed 701 (701/5000) ...
# Generating image for seed 702 (702/5000) ...
# Generating image for seed 703 (703/5000) ...
# Generating image for seed 704 (704/5000) ...
# Generating image for seed 705 (705/5000) ...
# Generating image for seed 706 (706/5000) ...
# Generating image for seed 707 (707/5000) ...
# Generating image for seed 708 (708/5000) ...
# Generating image for seed 709 (709/5000) ...
# Generating image for seed 710 (710/5000) ...
# Generating image for seed 711 (711/5000) ...
# Generating image for seed 712 (712/5000) ...
# Generating image for seed 713 (713/5000) ...
# Generating image for seed 714 (714/5000) ...
# Generating image for seed 715 (715/5000) ...
# Generating image for seed 716 (716/5000) ...
# Generating image for seed 717 (717/5000) ...
# Generating image for seed 718 (718/5000) ...
# Generating image for seed 719 (719/5000) ...
# Generating image for seed 720 (720/5000) ...
# Generating image for seed 721 (721/5000) ...
# Generating image for seed 722 (722/5000) ...
# Generating image for seed 723 (723/5000) ...
# Generating image for seed 724 (724/5000) ...
# Generating image for seed 725 (725/5000) ...
# Generating image for seed 726 (726/5000) ...
# Generating image for seed 727 (727/5000) ...
# Generating image for seed 728 (728/5000) ...
# Generating image for seed 729 (729/5000) ...
# Generating image for seed 730 (730/5000) ...
# Generating image for seed 731 (731/5000) ...
# Generating image for seed 732 (732/5000) ...
# Generating image for seed 733 (733/5000) ...
# Generating image for seed 734 (734/5000) ...
# Generating image for seed 735 (735/5000) ...
# Generating image for seed 736 (736/5000) ...
# Generating image for seed 737 (737/5000) ...
# Generating image for seed 738 (738/5000) ...
# Generating image for seed 739 (739/5000) ...
# Generating image for seed 740 (740/5000) ...
# Generating image for seed 741 (741/5000) ...
# Generating image for seed 742 (742/5000) ...
# Generating image for seed 743 (743/5000) ...
# Generating image for seed 744 (744/5000) ...
# Generating image for seed 745 (745/5000) ...
# Generating image for seed 746 (746/5000) ...
# Generating image for seed 747 (747/5000) ...
# Generating image for seed 748 (748/5000) ...
# Generating image for seed 749 (749/5000) ...
# Generating image for seed 750 (750/5000) ...
# Generating image for seed 751 (751/5000) ...
# Generating image for seed 752 (752/5000) ...
# Generating image for seed 753 (753/5000) ...
# Generating image for seed 754 (754/5000) ...
# Generating image for seed 755 (755/5000) ...
# Generating image for seed 756 (756/5000) ...
# Generating image for seed 757 (757/5000) ...
# Generating image for seed 758 (758/5000) ...
# Generating image for seed 759 (759/5000) ...
# Generating image for seed 760 (760/5000) ...
# Generating image for seed 761 (761/5000) ...
# Generating image for seed 762 (762/5000) ...
# Generating image for seed 763 (763/5000) ...
# Generating image for seed 764 (764/5000) ...
# Generating image for seed 765 (765/5000) ...
# Generating image for seed 766 (766/5000) ...
# Generating image for seed 767 (767/5000) ...
# Generating image for seed 768 (768/5000) ...
# Generating image for seed 769 (769/5000) ...
# Generating image for seed 770 (770/5000) ...
# Generating image for seed 771 (771/5000) ...
# Generating image for seed 772 (772/5000) ...
# Generating image for seed 773 (773/5000) ...
# Generating image for seed 774 (774/5000) ...
# Generating image for seed 775 (775/5000) ...
# Generating image for seed 776 (776/5000) ...
# Generating image for seed 777 (777/5000) ...
# Generating image for seed 778 (778/5000) ...
# Generating image for seed 779 (779/5000) ...
# Generating image for seed 780 (780/5000) ...
# Generating image for seed 781 (781/5000) ...
# Generating image for seed 782 (782/5000) ...
# Generating image for seed 783 (783/5000) ...
# Generating image for seed 784 (784/5000) ...
# Generating image for seed 785 (785/5000) ...
# Generating image for seed 786 (786/5000) ...
# Generating image for seed 787 (787/5000) ...
# Generating image for seed 788 (788/5000) ...
# Generating image for seed 789 (789/5000) ...
# Generating image for seed 790 (790/5000) ...
# Generating image for seed 791 (791/5000) ...
# Generating image for seed 792 (792/5000) ...
# Generating image for seed 793 (793/5000) ...
# Generating image for seed 794 (794/5000) ...
# Generating image for seed 795 (795/5000) ...
# Generating image for seed 796 (796/5000) ...
# Generating image for seed 797 (797/5000) ...
# Generating image for seed 798 (798/5000) ...
# Generating image for seed 799 (799/5000) ...
# Generating image for seed 800 (800/5000) ...
# Generating image for seed 801 (801/5000) ...
# Generating image for seed 802 (802/5000) ...
# Generating image for seed 803 (803/5000) ...
# Generating image for seed 804 (804/5000) ...
# Generating image for seed 805 (805/5000) ...
# Generating image for seed 806 (806/5000) ...
# Generating image for seed 807 (807/5000) ...
# Generating image for seed 808 (808/5000) ...
# Generating image for seed 809 (809/5000) ...
# Generating image for seed 810 (810/5000) ...
# Generating image for seed 811 (811/5000) ...
# Generating image for seed 812 (812/5000) ...
# Generating image for seed 813 (813/5000) ...
# Generating image for seed 814 (814/5000) ...
# Generating image for seed 815 (815/5000) ...
# Generating image for seed 816 (816/5000) ...
# Generating image for seed 817 (817/5000) ...
# Generating image for seed 818 (818/5000) ...
# Generating image for seed 819 (819/5000) ...
# Generating image for seed 820 (820/5000) ...
# Generating image for seed 821 (821/5000) ...
# Generating image for seed 822 (822/5000) ...
# Generating image for seed 823 (823/5000) ...
# Generating image for seed 824 (824/5000) ...
# Generating image for seed 825 (825/5000) ...
# Generating image for seed 826 (826/5000) ...
# Generating image for seed 827 (827/5000) ...
# Generating image for seed 828 (828/5000) ...
# Generating image for seed 829 (829/5000) ...
# Generating image for seed 830 (830/5000) ...
# Generating image for seed 831 (831/5000) ...
# Generating image for seed 832 (832/5000) ...
# Generating image for seed 833 (833/5000) ...
# Generating image for seed 834 (834/5000) ...
# Generating image for seed 835 (835/5000) ...
# Generating image for seed 836 (836/5000) ...
# Generating image for seed 837 (837/5000) ...
# Generating image for seed 838 (838/5000) ...
# Generating image for seed 839 (839/5000) ...
# Generating image for seed 840 (840/5000) ...
# Generating image for seed 841 (841/5000) ...
# Generating image for seed 842 (842/5000) ...
# Generating image for seed 843 (843/5000) ...
# Generating image for seed 844 (844/5000) ...
# Generating image for seed 845 (845/5000) ...
# Generating image for seed 846 (846/5000) ...
# Generating image for seed 847 (847/5000) ...
# Generating image for seed 848 (848/5000) ...
# Generating image for seed 849 (849/5000) ...
# Generating image for seed 850 (850/5000) ...
# Generating image for seed 851 (851/5000) ...
# Generating image for seed 852 (852/5000) ...
# Generating image for seed 853 (853/5000) ...
# Generating image for seed 854 (854/5000) ...
# Generating image for seed 855 (855/5000) ...
# Generating image for seed 856 (856/5000) ...
# Generating image for seed 857 (857/5000) ...
# Generating image for seed 858 (858/5000) ...
# Generating image for seed 859 (859/5000) ...
# Generating image for seed 860 (860/5000) ...
# Generating image for seed 861 (861/5000) ...
# Generating image for seed 862 (862/5000) ...
# Generating image for seed 863 (863/5000) ...
# Generating image for seed 864 (864/5000) ...
# Generating image for seed 865 (865/5000) ...
# Generating image for seed 866 (866/5000) ...
# Generating image for seed 867 (867/5000) ...
# Generating image for seed 868 (868/5000) ...
# Generating image for seed 869 (869/5000) ...
# Generating image for seed 870 (870/5000) ...
# Generating image for seed 871 (871/5000) ...
# Generating image for seed 872 (872/5000) ...
# Generating image for seed 873 (873/5000) ...
# Generating image for seed 874 (874/5000) ...
# Generating image for seed 875 (875/5000) ...
# Generating image for seed 876 (876/5000) ...
# Generating image for seed 877 (877/5000) ...
# Generating image for seed 878 (878/5000) ...
# Generating image for seed 879 (879/5000) ...
# Generating image for seed 880 (880/5000) ...
# Generating image for seed 881 (881/5000) ...
# Generating image for seed 882 (882/5000) ...
# Generating image for seed 883 (883/5000) ...
# Generating image for seed 884 (884/5000) ...
# Generating image for seed 885 (885/5000) ...
# Generating image for seed 886 (886/5000) ...
# Generating image for seed 887 (887/5000) ...
# Generating image for seed 888 (888/5000) ...
# Generating image for seed 889 (889/5000) ...
# Generating image for seed 890 (890/5000) ...
# Generating image for seed 891 (891/5000) ...
# Generating image for seed 892 (892/5000) ...
# Generating image for seed 893 (893/5000) ...
# Generating image for seed 894 (894/5000) ...
# Generating image for seed 895 (895/5000) ...
# Generating image for seed 896 (896/5000) ...
# Generating image for seed 897 (897/5000) ...
# Generating image for seed 898 (898/5000) ...
# Generating image for seed 899 (899/5000) ...
# Generating image for seed 900 (900/5000) ...
# Generating image for seed 901 (901/5000) ...
# Generating image for seed 902 (902/5000) ...
# Generating image for seed 903 (903/5000) ...
# Generating image for seed 904 (904/5000) ...
# Generating image for seed 905 (905/5000) ...
# Generating image for seed 906 (906/5000) ...
# Generating image for seed 907 (907/5000) ...
# Generating image for seed 908 (908/5000) ...
# Generating image for seed 909 (909/5000) ...
# Generating image for seed 910 (910/5000) ...
# Generating image for seed 911 (911/5000) ...
# Generating image for seed 912 (912/5000) ...
# Generating image for seed 913 (913/5000) ...
# Generating image for seed 914 (914/5000) ...
# Generating image for seed 915 (915/5000) ...
# Generating image for seed 916 (916/5000) ...
# Generating image for seed 917 (917/5000) ...
# Generating image for seed 918 (918/5000) ...
# Generating image for seed 919 (919/5000) ...
# Generating image for seed 920 (920/5000) ...
# Generating image for seed 921 (921/5000) ...
# Generating image for seed 922 (922/5000) ...
# Generating image for seed 923 (923/5000) ...
# Generating image for seed 924 (924/5000) ...
# Generating image for seed 925 (925/5000) ...
# Generating image for seed 926 (926/5000) ...
# Generating image for seed 927 (927/5000) ...
# Generating image for seed 928 (928/5000) ...
# Generating image for seed 929 (929/5000) ...
# Generating image for seed 930 (930/5000) ...
# Generating image for seed 931 (931/5000) ...
# Generating image for seed 932 (932/5000) ...
# Generating image for seed 933 (933/5000) ...
# Generating image for seed 934 (934/5000) ...
# Generating image for seed 935 (935/5000) ...
# Generating image for seed 936 (936/5000) ...
# Generating image for seed 937 (937/5000) ...
# Generating image for seed 938 (938/5000) ...
# Generating image for seed 939 (939/5000) ...
# Generating image for seed 940 (940/5000) ...
# Generating image for seed 941 (941/5000) ...
# Generating image for seed 942 (942/5000) ...
# Generating image for seed 943 (943/5000) ...
# Generating image for seed 944 (944/5000) ...
# Generating image for seed 945 (945/5000) ...
# Generating image for seed 946 (946/5000) ...
# Generating image for seed 947 (947/5000) ...
# Generating image for seed 948 (948/5000) ...
# Generating image for seed 949 (949/5000) ...
# Generating image for seed 950 (950/5000) ...
# Generating image for seed 951 (951/5000) ...
# Generating image for seed 952 (952/5000) ...
# Generating image for seed 953 (953/5000) ...
# Generating image for seed 954 (954/5000) ...
# Generating image for seed 955 (955/5000) ...
# Generating image for seed 956 (956/5000) ...
# Generating image for seed 957 (957/5000) ...
# Generating image for seed 958 (958/5000) ...
# Generating image for seed 959 (959/5000) ...
# Generating image for seed 960 (960/5000) ...
# Generating image for seed 961 (961/5000) ...
# Generating image for seed 962 (962/5000) ...
# Generating image for seed 963 (963/5000) ...
# Generating image for seed 964 (964/5000) ...
# Generating image for seed 965 (965/5000) ...
# Generating image for seed 966 (966/5000) ...
# Generating image for seed 967 (967/5000) ...
# Generating image for seed 968 (968/5000) ...
# Generating image for seed 969 (969/5000) ...
# Generating image for seed 970 (970/5000) ...
# Generating image for seed 971 (971/5000) ...
# Generating image for seed 972 (972/5000) ...
# Generating image for seed 973 (973/5000) ...
# Generating image for seed 974 (974/5000) ...
# Generating image for seed 975 (975/5000) ...
# Generating image for seed 976 (976/5000) ...
# Generating image for seed 977 (977/5000) ...
# Generating image for seed 978 (978/5000) ...
# Generating image for seed 979 (979/5000) ...
# Generating image for seed 980 (980/5000) ...
# Generating image for seed 981 (981/5000) ...
# Generating image for seed 982 (982/5000) ...
# Generating image for seed 983 (983/5000) ...
# Generating image for seed 984 (984/5000) ...
# Generating image for seed 985 (985/5000) ...
# Generating image for seed 986 (986/5000) ...
# Generating image for seed 987 (987/5000) ...
# Generating image for seed 988 (988/5000) ...
# Generating image for seed 989 (989/5000) ...
# Generating image for seed 990 (990/5000) ...
# Generating image for seed 991 (991/5000) ...
# Generating image for seed 992 (992/5000) ...
# Generating image for seed 993 (993/5000) ...
# Generating image for seed 994 (994/5000) ...
# Generating image for seed 995 (995/5000) ...
# Generating image for seed 996 (996/5000) ...
# Generating image for seed 997 (997/5000) ...
# Generating image for seed 998 (998/5000) ...
# Generating image for seed 999 (999/5000) ...
# Generating image for seed 1000 (1000/5000) ...
# Generating image for seed 1001 (1001/5000) ...
# Generating image for seed 1002 (1002/5000) ...
# Generating image for seed 1003 (1003/5000) ...
# Generating image for seed 1004 (1004/5000) ...
# Generating image for seed 1005 (1005/5000) ...
# Generating image for seed 1006 (1006/5000) ...
# Generating image for seed 1007 (1007/5000) ...
# Generating image for seed 1008 (1008/5000) ...
# Generating image for seed 1009 (1009/5000) ...
# Generating image for seed 1010 (1010/5000) ...
# Generating image for seed 1011 (1011/5000) ...
# Generating image for seed 1012 (1012/5000) ...
# Generating image for seed 1013 (1013/5000) ...
# Generating image for seed 1014 (1014/5000) ...
# Generating image for seed 1015 (1015/5000) ...
# Generating image for seed 1016 (1016/5000) ...
# Generating image for seed 1017 (1017/5000) ...
# Generating image for seed 1018 (1018/5000) ...
# Generating image for seed 1019 (1019/5000) ...
# Generating image for seed 1020 (1020/5000) ...
# Generating image for seed 1021 (1021/5000) ...
# Generating image for seed 1022 (1022/5000) ...
# Generating image for seed 1023 (1023/5000) ...
# Generating image for seed 1024 (1024/5000) ...
# Generating image for seed 1025 (1025/5000) ...
# Generating image for seed 1026 (1026/5000) ...
# Generating image for seed 1027 (1027/5000) ...
# Generating image for seed 1028 (1028/5000) ...
# Generating image for seed 1029 (1029/5000) ...
# Generating image for seed 1030 (1030/5000) ...
# Generating image for seed 1031 (1031/5000) ...
# Generating image for seed 1032 (1032/5000) ...
# Generating image for seed 1033 (1033/5000) ...
# Generating image for seed 1034 (1034/5000) ...
# Generating image for seed 1035 (1035/5000) ...
# Generating image for seed 1036 (1036/5000) ...
# Generating image for seed 1037 (1037/5000) ...
# Generating image for seed 1038 (1038/5000) ...
# Generating image for seed 1039 (1039/5000) ...
# Generating image for seed 1040 (1040/5000) ...
# Generating image for seed 1041 (1041/5000) ...
# Generating image for seed 1042 (1042/5000) ...
# Generating image for seed 1043 (1043/5000) ...
# Generating image for seed 1044 (1044/5000) ...
# Generating image for seed 1045 (1045/5000) ...
# Generating image for seed 1046 (1046/5000) ...
# Generating image for seed 1047 (1047/5000) ...
# Generating image for seed 1048 (1048/5000) ...
# Generating image for seed 1049 (1049/5000) ...
# Generating image for seed 1050 (1050/5000) ...
# Generating image for seed 1051 (1051/5000) ...
# Generating image for seed 1052 (1052/5000) ...
# Generating image for seed 1053 (1053/5000) ...
# Generating image for seed 1054 (1054/5000) ...
# Generating image for seed 1055 (1055/5000) ...
# Generating image for seed 1056 (1056/5000) ...
# Generating image for seed 1057 (1057/5000) ...
# Generating image for seed 1058 (1058/5000) ...
# Generating image for seed 1059 (1059/5000) ...
# Generating image for seed 1060 (1060/5000) ...
# Generating image for seed 1061 (1061/5000) ...
# Generating image for seed 1062 (1062/5000) ...
# Generating image for seed 1063 (1063/5000) ...
# Generating image for seed 1064 (1064/5000) ...
# Generating image for seed 1065 (1065/5000) ...
# Generating image for seed 1066 (1066/5000) ...
# ...
# Generating image for seed 4660 (4660/5000) ...
# Generating image for seed 4661 (4661/5000) ...
# Generating image for seed 4662 (4662/5000) ...
# Generating image for seed 4663 (4663/5000) ...
# Generating image for seed 4664 (4664/5000) ...
# Generating image for seed 4665 (4665/5000) ...
# Generating image for seed 4666 (4666/5000) ...
# Generating image for seed 4667 (4667/5000) ...
# Generating image for seed 4668 (4668/5000) ...
# Generating image for seed 4669 (4669/5000) ...
# Generating image for seed 4670 (4670/5000) ...
# Generating image for seed 4671 (4671/5000) ...
# Generating image for seed 4672 (4672/5000) ...
# Generating image for seed 4673 (4673/5000) ...
# Generating image for seed 4674 (4674/5000) ...
# Generating image for seed 4675 (4675/5000) ...
# Generating image for seed 4676 (4676/5000) ...
# Generating image for seed 4677 (4677/5000) ...
# Generating image for seed 4678 (4678/5000) ...
# Generating image for seed 4679 (4679/5000) ...
# Generating image for seed 4680 (4680/5000) ...
# Generating image for seed 4681 (4681/5000) ...
# Generating image for seed 4682 (4682/5000) ...
# Generating image for seed 4683 (4683/5000) ...
# Generating image for seed 4684 (4684/5000) ...
# Generating image for seed 4685 (4685/5000) ...
# Generating image for seed 4686 (4686/5000) ...
# Generating image for seed 4687 (4687/5000) ...
# Generating image for seed 4688 (4688/5000) ...
# Generating image for seed 4689 (4689/5000) ...
# Generating image for seed 4690 (4690/5000) ...
# Generating image for seed 4691 (4691/5000) ...
# Generating image for seed 4692 (4692/5000) ...
# Generating image for seed 4693 (4693/5000) ...
# Generating image for seed 4694 (4694/5000) ...
# Generating image for seed 4695 (4695/5000) ...
# Generating image for seed 4696 (4696/5000) ...
# Generating image for seed 4697 (4697/5000) ...
# Generating image for seed 4698 (4698/5000) ...
# Generating image for seed 4699 (4699/5000) ...
# Generating image for seed 4700 (4700/5000) ...
# Generating image for seed 4701 (4701/5000) ...
# Generating image for seed 4702 (4702/5000) ...
# Generating image for seed 4703 (4703/5000) ...
# Generating image for seed 4704 (4704/5000) ...
# Generating image for seed 4705 (4705/5000) ...
# Generating image for seed 4706 (4706/5000) ...
# Generating image for seed 4707 (4707/5000) ...
# Generating image for seed 4708 (4708/5000) ...
# Generating image for seed 4709 (4709/5000) ...
# Generating image for seed 4710 (4710/5000) ...
# Generating image for seed 4711 (4711/5000) ...
# Generating image for seed 4712 (4712/5000) ...
# Generating image for seed 4713 (4713/5000) ...
# Generating image for seed 4714 (4714/5000) ...
# Generating image for seed 4715 (4715/5000) ...
# Generating image for seed 4716 (4716/5000) ...
# Generating image for seed 4717 (4717/5000) ...
# Generating image for seed 4718 (4718/5000) ...
# Generating image for seed 4719 (4719/5000) ...
# Generating image for seed 4720 (4720/5000) ...
# Generating image for seed 4721 (4721/5000) ...
# Generating image for seed 4722 (4722/5000) ...
# Generating image for seed 4723 (4723/5000) ...
# Generating image for seed 4724 (4724/5000) ...
# Generating image for seed 4725 (4725/5000) ...
# Generating image for seed 4726 (4726/5000) ...
# Generating image for seed 4727 (4727/5000) ...
# Generating image for seed 4728 (4728/5000) ...
# Generating image for seed 4729 (4729/5000) ...
# Generating image for seed 4730 (4730/5000) ...
# Generating image for seed 4731 (4731/5000) ...
# Generating image for seed 4732 (4732/5000) ...
# Generating image for seed 4733 (4733/5000) ...
# Generating image for seed 4734 (4734/5000) ...
# Generating image for seed 4735 (4735/5000) ...
# Generating image for seed 4736 (4736/5000) ...
# Generating image for seed 4737 (4737/5000) ...
# Generating image for seed 4738 (4738/5000) ...
# Generating image for seed 4739 (4739/5000) ...
# Generating image for seed 4740 (4740/5000) ...
# Generating image for seed 4741 (4741/5000) ...
# Generating image for seed 4742 (4742/5000) ...
# Generating image for seed 4743 (4743/5000) ...
# Generating image for seed 4744 (4744/5000) ...
# Generating image for seed 4745 (4745/5000) ...
# Generating image for seed 4746 (4746/5000) ...
# Generating image for seed 4747 (4747/5000) ...
# Generating image for seed 4748 (4748/5000) ...
# Generating image for seed 4749 (4749/5000) ...
# Generating image for seed 4750 (4750/5000) ...
# Generating image for seed 4751 (4751/5000) ...
# Generating image for seed 4752 (4752/5000) ...
# Generating image for seed 4753 (4753/5000) ...
# Generating image for seed 4754 (4754/5000) ...
# Generating image for seed 4755 (4755/5000) ...
# Generating image for seed 4756 (4756/5000) ...
# Generating image for seed 4757 (4757/5000) ...
# Generating image for seed 4758 (4758/5000) ...
# Generating image for seed 4759 (4759/5000) ...
# Generating image for seed 4760 (4760/5000) ...
# Generating image for seed 4761 (4761/5000) ...
# Generating image for seed 4762 (4762/5000) ...
# Generating image for seed 4763 (4763/5000) ...
# Generating image for seed 4764 (4764/5000) ...
# Generating image for seed 4765 (4765/5000) ...
# Generating image for seed 4766 (4766/5000) ...
# Generating image for seed 4767 (4767/5000) ...
# Generating image for seed 4768 (4768/5000) ...
# Generating image for seed 4769 (4769/5000) ...
# Generating image for seed 4770 (4770/5000) ...
# Generating image for seed 4771 (4771/5000) ...
# Generating image for seed 4772 (4772/5000) ...
# Generating image for seed 4773 (4773/5000) ...
# Generating image for seed 4774 (4774/5000) ...
# Generating image for seed 4775 (4775/5000) ...
# Generating image for seed 4776 (4776/5000) ...
# Generating image for seed 4777 (4777/5000) ...
# Generating image for seed 4778 (4778/5000) ...
# Generating image for seed 4779 (4779/5000) ...
# Generating image for seed 4780 (4780/5000) ...
# Generating image for seed 4781 (4781/5000) ...
# Generating image for seed 4782 (4782/5000) ...
# Generating image for seed 4783 (4783/5000) ...
# Generating image for seed 4784 (4784/5000) ...
# Generating image for seed 4785 (4785/5000) ...
# Generating image for seed 4786 (4786/5000) ...
# Generating image for seed 4787 (4787/5000) ...
# Generating image for seed 4788 (4788/5000) ...
# Generating image for seed 4789 (4789/5000) ...
# Generating image for seed 4790 (4790/5000) ...
# Generating image for seed 4791 (4791/5000) ...
# Generating image for seed 4792 (4792/5000) ...
# Generating image for seed 4793 (4793/5000) ...
# Generating image for seed 4794 (4794/5000) ...
# Generating image for seed 4795 (4795/5000) ...
# Generating image for seed 4796 (4796/5000) ...
# Generating image for seed 4797 (4797/5000) ...
# Generating image for seed 4798 (4798/5000) ...
# Generating image for seed 4799 (4799/5000) ...
# Generating image for seed 4800 (4800/5000) ...
# Generating image for seed 4801 (4801/5000) ...
# Generating image for seed 4802 (4802/5000) ...
# Generating image for seed 4803 (4803/5000) ...
# Generating image for seed 4804 (4804/5000) ...
# Generating image for seed 4805 (4805/5000) ...
# Generating image for seed 4806 (4806/5000) ...
# Generating image for seed 4807 (4807/5000) ...
# Generating image for seed 4808 (4808/5000) ...
# Generating image for seed 4809 (4809/5000) ...
# Generating image for seed 4810 (4810/5000) ...
# Generating image for seed 4811 (4811/5000) ...
# Generating image for seed 4812 (4812/5000) ...
# Generating image for seed 4813 (4813/5000) ...
# Generating image for seed 4814 (4814/5000) ...
# Generating image for seed 4815 (4815/5000) ...
# Generating image for seed 4816 (4816/5000) ...
# Generating image for seed 4817 (4817/5000) ...
# Generating image for seed 4818 (4818/5000) ...
# Generating image for seed 4819 (4819/5000) ...
# Generating image for seed 4820 (4820/5000) ...
# Generating image for seed 4821 (4821/5000) ...
# Generating image for seed 4822 (4822/5000) ...
# Generating image for seed 4823 (4823/5000) ...
# Generating image for seed 4824 (4824/5000) ...
# Generating image for seed 4825 (4825/5000) ...
# Generating image for seed 4826 (4826/5000) ...
# Generating image for seed 4827 (4827/5000) ...
# Generating image for seed 4828 (4828/5000) ...
# Generating image for seed 4829 (4829/5000) ...
# Generating image for seed 4830 (4830/5000) ...
# Generating image for seed 4831 (4831/5000) ...
# Generating image for seed 4832 (4832/5000) ...
# Generating image for seed 4833 (4833/5000) ...
# Generating image for seed 4834 (4834/5000) ...
# Generating image for seed 4835 (4835/5000) ...
# Generating image for seed 4836 (4836/5000) ...
# Generating image for seed 4837 (4837/5000) ...
# Generating image for seed 4838 (4838/5000) ...
# Generating image for seed 4839 (4839/5000) ...
# Generating image for seed 4840 (4840/5000) ...
# Generating image for seed 4841 (4841/5000) ...
# Generating image for seed 4842 (4842/5000) ...
# Generating image for seed 4843 (4843/5000) ...
# Generating image for seed 4844 (4844/5000) ...
# Generating image for seed 4845 (4845/5000) ...
# Generating image for seed 4846 (4846/5000) ...
# Generating image for seed 4847 (4847/5000) ...
# Generating image for seed 4848 (4848/5000) ...
# Generating image for seed 4849 (4849/5000) ...
# Generating image for seed 4850 (4850/5000) ...
# Generating image for seed 4851 (4851/5000) ...
# Generating image for seed 4852 (4852/5000) ...
# Generating image for seed 4853 (4853/5000) ...
# Generating image for seed 4854 (4854/5000) ...
# Generating image for seed 4855 (4855/5000) ...
# Generating image for seed 4856 (4856/5000) ...
# Generating image for seed 4857 (4857/5000) ...
# Generating image for seed 4858 (4858/5000) ...
# Generating image for seed 4859 (4859/5000) ...
# Generating image for seed 4860 (4860/5000) ...
# Generating image for seed 4861 (4861/5000) ...
# Generating image for seed 4862 (4862/5000) ...
# Generating image for seed 4863 (4863/5000) ...
# Generating image for seed 4864 (4864/5000) ...
# Generating image for seed 4865 (4865/5000) ...
# Generating image for seed 4866 (4866/5000) ...
# Generating image for seed 4867 (4867/5000) ...
# Generating image for seed 4868 (4868/5000) ...
# Generating image for seed 4869 (4869/5000) ...
# Generating image for seed 4870 (4870/5000) ...
# Generating image for seed 4871 (4871/5000) ...
# Generating image for seed 4872 (4872/5000) ...
# Generating image for seed 4873 (4873/5000) ...
# Generating image for seed 4874 (4874/5000) ...
# Generating image for seed 4875 (4875/5000) ...
# Generating image for seed 4876 (4876/5000) ...
# Generating image for seed 4877 (4877/5000) ...
# Generating image for seed 4878 (4878/5000) ...
# Generating image for seed 4879 (4879/5000) ...
# Generating image for seed 4880 (4880/5000) ...
# Generating image for seed 4881 (4881/5000) ...
# Generating image for seed 4882 (4882/5000) ...
# Generating image for seed 4883 (4883/5000) ...
# Generating image for seed 4884 (4884/5000) ...
# Generating image for seed 4885 (4885/5000) ...
# Generating image for seed 4886 (4886/5000) ...
# Generating image for seed 4887 (4887/5000) ...
# Generating image for seed 4888 (4888/5000) ...
# Generating image for seed 4889 (4889/5000) ...
# Generating image for seed 4890 (4890/5000) ...
# Generating image for seed 4891 (4891/5000) ...
# Generating image for seed 4892 (4892/5000) ...
# Generating image for seed 4893 (4893/5000) ...
# Generating image for seed 4894 (4894/5000) ...
# Generating image for seed 4895 (4895/5000) ...
# Generating image for seed 4896 (4896/5000) ...
# Generating image for seed 4897 (4897/5000) ...
# Generating image for seed 4898 (4898/5000) ...
# Generating image for seed 4899 (4899/5000) ...
# Generating image for seed 4900 (4900/5000) ...
# Generating image for seed 4901 (4901/5000) ...
# Generating image for seed 4902 (4902/5000) ...
# Generating image for seed 4903 (4903/5000) ...
# Generating image for seed 4904 (4904/5000) ...
# Generating image for seed 4905 (4905/5000) ...
# Generating image for seed 4906 (4906/5000) ...
# Generating image for seed 4907 (4907/5000) ...
# Generating image for seed 4908 (4908/5000) ...
# Generating image for seed 4909 (4909/5000) ...
# Generating image for seed 4910 (4910/5000) ...
# Generating image for seed 4911 (4911/5000) ...
# Generating image for seed 4912 (4912/5000) ...
# Generating image for seed 4913 (4913/5000) ...
# Generating image for seed 4914 (4914/5000) ...
# Generating image for seed 4915 (4915/5000) ...
# Generating image for seed 4916 (4916/5000) ...
# Generating image for seed 4917 (4917/5000) ...
# Generating image for seed 4918 (4918/5000) ...
# Generating image for seed 4919 (4919/5000) ...
# Generating image for seed 4920 (4920/5000) ...
# Generating image for seed 4921 (4921/5000) ...
# Generating image for seed 4922 (4922/5000) ...
# Generating image for seed 4923 (4923/5000) ...
# Generating image for seed 4924 (4924/5000) ...
# Generating image for seed 4925 (4925/5000) ...
# Generating image for seed 4926 (4926/5000) ...
# Generating image for seed 4927 (4927/5000) ...
# Generating image for seed 4928 (4928/5000) ...
# Generating image for seed 4929 (4929/5000) ...
# Generating image for seed 4930 (4930/5000) ...
# Generating image for seed 4931 (4931/5000) ...
# Generating image for seed 4932 (4932/5000) ...
# Generating image for seed 4933 (4933/5000) ...
# Generating image for seed 4934 (4934/5000) ...
# Generating image for seed 4935 (4935/5000) ...
# Generating image for seed 4936 (4936/5000) ...
# Generating image for seed 4937 (4937/5000) ...
# Generating image for seed 4938 (4938/5000) ...
# Generating image for seed 4939 (4939/5000) ...
# Generating image for seed 4940 (4940/5000) ...
# Generating image for seed 4941 (4941/5000) ...
# Generating image for seed 4942 (4942/5000) ...
# Generating image for seed 4943 (4943/5000) ...
# Generating image for seed 4944 (4944/5000) ...
# Generating image for seed 4945 (4945/5000) ...
# Generating image for seed 4946 (4946/5000) ...
# Generating image for seed 4947 (4947/5000) ...
# Generating image for seed 4948 (4948/5000) ...
# Generating image for seed 4949 (4949/5000) ...
# Generating image for seed 4950 (4950/5000) ...
# Generating image for seed 4951 (4951/5000) ...
# Generating image for seed 4952 (4952/5000) ...
# Generating image for seed 4953 (4953/5000) ...
# Generating image for seed 4954 (4954/5000) ...
# Generating image for seed 4955 (4955/5000) ...
# Generating image for seed 4956 (4956/5000) ...
# Generating image for seed 4957 (4957/5000) ...
# Generating image for seed 4958 (4958/5000) ...
# Generating image for seed 4959 (4959/5000) ...
# Generating image for seed 4960 (4960/5000) ...
# Generating image for seed 4961 (4961/5000) ...
# Generating image for seed 4962 (4962/5000) ...
# Generating image for seed 4963 (4963/5000) ...
# Generating image for seed 4964 (4964/5000) ...
# Generating image for seed 4965 (4965/5000) ...
# Generating image for seed 4966 (4966/5000) ...
# Generating image for seed 4967 (4967/5000) ...
# Generating image for seed 4968 (4968/5000) ...
# Generating image for seed 4969 (4969/5000) ...
# Generating image for seed 4970 (4970/5000) ...
# Generating image for seed 4971 (4971/5000) ...
# Generating image for seed 4972 (4972/5000) ...
# Generating image for seed 4973 (4973/5000) ...
# Generating image for seed 4974 (4974/5000) ...
# Generating image for seed 4975 (4975/5000) ...
# Generating image for seed 4976 (4976/5000) ...
# Generating image for seed 4977 (4977/5000) ...
# Generating image for seed 4978 (4978/5000) ...
# Generating image for seed 4979 (4979/5000) ...
# Generating image for seed 4980 (4980/5000) ...
# Generating image for seed 4981 (4981/5000) ...
# Generating image for seed 4982 (4982/5000) ...
# Generating image for seed 4983 (4983/5000) ...
# Generating image for seed 4984 (4984/5000) ...
# Generating image for seed 4985 (4985/5000) ...
# Generating image for seed 4986 (4986/5000) ...
# Generating image for seed 4987 (4987/5000) ...
# Generating image for seed 4988 (4988/5000) ...
# Generating image for seed 4989 (4989/5000) ...
# Generating image for seed 4990 (4990/5000) ...
# Generating image for seed 4991 (4991/5000) ...
# Generating image for seed 4992 (4992/5000) ...
# Generating image for seed 4993 (4993/5000) ...
# Generating image for seed 4994 (4994/5000) ...
# Generating image for seed 4995 (4995/5000) ...
# Generating image for seed 4996 (4996/5000) ...
# Generating image for seed 4997 (4997/5000) ...
# Generating image for seed 4998 (4998/5000) ...
# Generating image for seed 4999 (4999/5000) ...

# %%
# !mv out ../

# %%
os.chdir('../')

# %%
import shutil
from PIL import Image
import os

# Paths to the source and destination directories
src_directory = 'out'
dst_train_fake = 'original/train/fake'
dst_val_fake = 'original/val/fake'
dst_test_fake = 'original/test/fake'

# Ensure the destination directories exist
os.makedirs(dst_train_fake, exist_ok=True)
os.makedirs(dst_val_fake, exist_ok=True)
os.makedirs(dst_test_fake, exist_ok=True)

# Function to resize and move a specific number of images to a destination directory
def resize_and_move_images(source, destination, count, size=(256, 256)):
    # Get all the image files in the source directory
    files = [file for file in os.listdir(source) if file.lower().endswith('.png')]
    # Resize and move the specified number of images
    for file in files[:count]:
        img_path = os.path.join(source, file)
        with Image.open(img_path) as img:
            # Resize the image
            img = img.resize(size, Image.BICUBIC)
            # Save the resized image to the destination directory
            img.save(os.path.join(destination, file))
        # Remove the original file after resizing and moving
        os.remove(img_path)

# Move and resize the images to their respective directories
resize_and_move_images(src_directory, dst_train_fake, 4000)  # First 4000 to train/fake
resize_and_move_images(src_directory, dst_val_fake, 500)     # Next 500 to val/fake
resize_and_move_images(src_directory, dst_test_fake, 500)    # Last 500 to test/fake

print("Images resized and moved successfully.")
# Out:
# Images resized and moved successfully.

# %%
import os

def count_images_in_directory(directory):
    # Initialize a counter
    count = 0
    # Walk through all files and directories within the given directory
    for root, dirs, files in os.walk(directory):
        # Count the number of PNG files
        count += len([file for file in files if file.endswith('.png')])
        print(f"There are {count} images in '{root}' directory.")
        # Reset the counter after printing out the count for the current directory
        count = 0

# Define the base path for the 'original' directory
base_original_dir = 'original'

# Call the function with the path to the 'original' directory
count_images_in_directory(base_original_dir)
# Out:
# There are 0 images in 'original' directory.
# There are 0 images in 'original/test' directory.
# There are 500 images in 'original/test/fake' directory.
# There are 500 images in 'original/test/real' directory.
# There are 0 images in 'original/train' directory.
# There are 4000 images in 'original/train/fake' directory.
# There are 4000 images in 'original/train/real' directory.
# There are 0 images in 'original/val' directory.
# There are 500 images in 'original/val/fake' directory.
# There are 500 images in 'original/val/real' directory.

# %% [markdown]
# ### Original Dataset Compiling

# %%
# !zip -r original_dataset.zip original/

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp original_dataset.zip /content/drive/MyDrive/TML_Project/data/

# %% [markdown]
# ### Initial Deep Learning Model Benchmarking

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model

# Load the pre-trained ResNet50 model
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(256, 256, 3))

# Freeze the layers of the base model
for layer in base_model.layers:
    layer.trainable = False

# Add new top layers
x = GlobalAveragePooling2D()(base_model.output)
predictions = Dense(2, activation='softmax')(x)  # Assuming binary classification (real vs fake)
model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Setup data generators
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    'original/train/',
    target_size=(256, 256),
    batch_size=32,
    class_mode='categorical'
)

validation_generator = val_datagen.flow_from_directory(
    'original/val/',
    target_size=(256, 256),
    batch_size=32,
    class_mode='categorical'
)

# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
    epochs=10
)

# Evaluate the model on the test set
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    'original/test/',
    target_size=(256, 256),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

# Evaluate on test data
results = model.evaluate(test_generator)
print(f"Test Loss: {results[0]}, Test Accuracy: {results[1]}")
# Out:
# Found 8000 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.
# Epoch 1/10
# 250/250 [==============================] - 54s 202ms/step - loss: 0.7082 - accuracy: 0.5086 - val_loss: 0.7258 - val_accuracy: 0.5030
# Epoch 2/10
# 250/250 [==============================] - 47s 189ms/step - loss: 0.7016 - accuracy: 0.5049 - val_loss: 0.7012 - val_accuracy: 0.5000
# Epoch 3/10
# 250/250 [==============================] - 47s 190ms/step - loss: 0.6967 - accuracy: 0.5111 - val_loss: 0.6930 - val_accuracy: 0.5121
# Epoch 4/10
# 250/250 [==============================] - 47s 188ms/step - loss: 0.6980 - accuracy: 0.5154 - val_loss: 0.7164 - val_accuracy: 0.4990
# Epoch 5/10
# 250/250 [==============================] - 49s 194ms/step - loss: 0.7025 - accuracy: 0.5185 - val_loss: 0.7059 - val_accuracy: 0.5050
# Epoch 6/10
# 250/250 [==============================] - 47s 187ms/step - loss: 0.7005 - accuracy: 0.5045 - val_loss: 0.7014 - val_accuracy: 0.5111
# Epoch 7/10
# 250/250 [==============================] - 48s 191ms/step - loss: 0.7013 - accuracy: 0.5124 - val_loss: 0.7087 - val_accuracy: 0.5010
# Epoch 8/10
# 250/250 [==============================] - 48s 191ms/step - loss: 0.7001 - accuracy: 0.5085 - val_loss: 0.6947 - val_accuracy: 0.5050
# Epoch 9/10
# 250/250 [==============================] - 48s 192ms/step - loss: 0.6971 - accuracy: 0.5234 - val_loss: 0.6946 - val_accuracy: 0.5000
# Epoch 10/10
# 250/250 [==============================] - 47s 188ms/step - loss: 0.6947 - accuracy: 0.5203 - val_loss: 0.7040 - val_accuracy: 0.5020
# Found 1000 images belonging to 2 classes.
# 32/32 [==============================] - 5s 156ms/step - loss: 0.7061 - accuracy: 0.5020
# Test Loss: 0.7061493992805481, Test Accuracy: 0.5019999742507935
