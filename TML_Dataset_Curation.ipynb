# %% [markdown]
# <a href="https://colab.research.google.com/github/SarveshPatil99/Adversarial-Robustness-Enhancement/blob/main/TML_Dataset_Curation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Directory Structure Creation for All Datasets

# %%
import os

def create_dataset_structure(base_path='original'):
    categories = ['train', 'val', 'test']
    types = ['real', 'fake']

    for category in categories:
        for image_type in types:
            # Construct the path to the directory
            dir_path = os.path.join(base_path, category, image_type)
            # Create the directory with nested structure
            # exist_ok=True is used to avoid error if the directory already exists
            os.makedirs(dir_path, exist_ok=True)
            print(f"Directory created: {dir_path}")

if __name__ == "__main__":
    create_dataset_structure()
# Out:
# Directory created: original/train/real
# Directory created: original/train/fake
# Directory created: original/val/real
# Directory created: original/val/fake
# Directory created: original/test/real
# Directory created: original/test/fake

# %%
import os

def create_noise_dataset_structure(base_paths):
    categories = ['train', 'val', 'test']
    types = ['real', 'fake']

    for base_path in base_paths:
        for category in categories:
            for image_type in types:
                # Construct the path to the directory
                dir_path = os.path.join(base_path, category, image_type)
                # Create the directory with nested structure
                # exist_ok=True is used to avoid error if the directory already exists
                os.makedirs(dir_path, exist_ok=True)
                print(f"Directory created: {dir_path}")

if __name__ == "__main__":
    noises = ['gaussian', 'uniform', 'salt_and_pepper', 'speckle']
    # Create a separate root folder for each type of noise
    base_paths = [f'noise_{noise}' for noise in noises]
    create_noise_dataset_structure(base_paths)
# Out:
# Directory created: noise_gaussian/train/real
# Directory created: noise_gaussian/train/fake
# Directory created: noise_gaussian/val/real
# Directory created: noise_gaussian/val/fake
# Directory created: noise_gaussian/test/real
# Directory created: noise_gaussian/test/fake
# Directory created: noise_uniform/train/real
# Directory created: noise_uniform/train/fake
# Directory created: noise_uniform/val/real
# Directory created: noise_uniform/val/fake
# Directory created: noise_uniform/test/real
# Directory created: noise_uniform/test/fake
# Directory created: noise_salt_and_pepper/train/real
# Directory created: noise_salt_and_pepper/train/fake
# Directory created: noise_salt_and_pepper/val/real
# Directory created: noise_salt_and_pepper/val/fake
# Directory created: noise_salt_and_pepper/test/real
# Directory created: noise_salt_and_pepper/test/fake
# Directory created: noise_speckle/train/real
# Directory created: noise_speckle/train/fake
# Directory created: noise_speckle/val/real
# Directory created: noise_speckle/val/fake
# Directory created: noise_speckle/test/real
# Directory created: noise_speckle/test/fake

# %%
import os

def create_mixed_dataset_structure(base_path, ratios):
    categories = ['train', 'val']
    types = ['real', 'fake']

    for ratio in ratios:
            # Construct the base path including the noise ratio
            ratio_path = f"{base_path}_{ratio}"
            for category in categories:
                for image_type in types:
                    # Construct the path to the directory
                    dir_path = os.path.join(ratio_path, category, image_type)
                    # Create the directory with nested structure
                    # exist_ok=True is used to avoid error if the directory already exists
                    os.makedirs(dir_path, exist_ok=True)
                    print(f"Directory created: {dir_path}")

if __name__ == "__main__":
    # Names of the noises will be determined after Phase II, but we prepare for all possibilities.
    noises = ['']
    # Ratios of original to noisy data
    ratios = ['1_1', '1_2', '2_1']

    # Create a base path for mixed datasets
    base_path = 'mixed_noise'
    create_mixed_dataset_structure(base_path, ratios)
# Out:
# Directory created: mixed_noise_1_1/train/real
# Directory created: mixed_noise_1_1/train/fake
# Directory created: mixed_noise_1_1/val/real
# Directory created: mixed_noise_1_1/val/fake
# Directory created: mixed_noise_1_2/train/real
# Directory created: mixed_noise_1_2/train/fake
# Directory created: mixed_noise_1_2/val/real
# Directory created: mixed_noise_1_2/val/fake
# Directory created: mixed_noise_2_1/train/real
# Directory created: mixed_noise_2_1/train/fake
# Directory created: mixed_noise_2_1/val/real
# Directory created: mixed_noise_2_1/val/fake

# %%
import os

# Define the adversarial attack types
adversarial_attacks = ['fgsm', 'bim', 'pgd']

# Directory structure for the test phase
dir_structure = {
    'test': ['real', 'fake']
}

# Create base directories for each adversarial attack type
for attack in adversarial_attacks:
    # Create a base directory for the current attack (e.g., 'fgsm_test')
    base_attack_dir = f'adversarial_{attack}'

    for phase in dir_structure:
        # Create a sub-directory for test (e.g., 'fgsm_test/test')
        phase_dir = os.path.join(base_attack_dir, phase)

        for category in dir_structure[phase]:
            # Create sub-directories for real and fake categories (e.g., 'fgsm_test/test/real')
            category_dir = os.path.join(phase_dir, category)
            os.makedirs(category_dir, exist_ok=True)
            print(f"Created directory: {category_dir}")
# Out:
# Created directory: adversarial_fgsm/test/real
# Created directory: adversarial_fgsm/test/fake
# Created directory: adversarial_bim/test/real
# Created directory: adversarial_bim/test/fake
# Created directory: adversarial_pgd/test/real
# Created directory: adversarial_pgd/test/fake

# %% [markdown]
# ### Real Dataset Curation

# %%
# !rm -r ~/.kaggle
# !mkdir ~/.kaggle
# !cp ./kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# rm: cannot remove '/root/.kaggle': No such file or directory

# %%
# !kaggle datasets download -d denislukovnikov/ffhq256-images-only
# Out:
# Downloading ffhq256-images-only.zip to /content
# 100% 6.90G/6.91G [01:13<00:00, 118MB/s]
# 100% 6.91G/6.91G [01:13<00:00, 100MB/s]

# %%
# !unzip -q ffhq256-images-only.zip

# %%
import os
import shutil

# Define the source and destination directories
source_dir = 'ffhq256'
destination_dir = 'real_images_directory'

# Create the destination directory if it doesn't already exist
os.makedirs(destination_dir, exist_ok=True)

# Iterate over the first 10,000 images and move them to the destination
for i in range(10000):
    # Format the filename with leading zeros
    file_name = f"{i:05d}.png"
    # Define the source and destination file paths
    source_file = os.path.join(source_dir, file_name)
    destination_file = os.path.join(destination_dir, file_name)

    # Move the file
    shutil.move(source_file, destination_file)

print(f"First 10,000 images moved to {destination_dir}.")
# Out:
# First 5,000 images moved to real_images_directory.

# %%
import os
import shutil

# Define the base path for the 'original' directory
base_original_dir = 'original'

# Define the directories for train, validation, and test sets
train_dir = os.path.join(base_original_dir, 'train', 'real')
val_dir = os.path.join(base_original_dir, 'val', 'real')
test_dir = os.path.join(base_original_dir, 'test', 'real')

# Create the directories if they don't exist
os.makedirs(train_dir, exist_ok=True)
os.makedirs(val_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

# Source directory containing all real images
source_dir = 'real_images_directory'

# Move the first 8000 images to the train directory
for i in range(8000):
    file_name = f"{i:05d}.png"
    source_file = os.path.join(source_dir, file_name)
    destination_file = os.path.join(train_dir, file_name)
    shutil.move(source_file, destination_file)

# Move the next 1000 images to the validation directory
for i in range(8000, 9000):
    file_name = f"{i:05d}.png"
    source_file = os.path.join(source_dir, file_name)
    destination_file = os.path.join(val_dir, file_name)
    shutil.move(source_file, destination_file)

# Move the last 1000 images to the test directory
for i in range(9000, 10000):
    file_name = f"{i:05d}.png"
    source_file = os.path.join(source_dir, file_name)
    destination_file = os.path.join(test_dir, file_name)
    shutil.move(source_file, destination_file)

print("Images distributed to train, val, and test directories.")
# Out:
# Images distributed to train, val, and test directories.

# %%
import os

def count_images_in_directory(directory):
    # Initialize a counter
    count = 0
    # Walk through all files and directories within the given directory
    for root, dirs, files in os.walk(directory):
        # Count the number of PNG files
        count += len([file for file in files if file.endswith('.png')])
        print(f"There are {count} images in '{root}' directory.")
        # Reset the counter after printing out the count for the current directory
        count = 0

# Define the base path for the 'original' directory
base_original_dir = 'original'

# Call the function with the path to the 'original' directory
count_images_in_directory(base_original_dir)
# Out:
# There are 0 images in 'original' directory.
# There are 0 images in 'original/test' directory.
# There are 0 images in 'original/test/fake' directory.
# There are 1000 images in 'original/test/real' directory.
# There are 0 images in 'original/train' directory.
# There are 0 images in 'original/train/fake' directory.
# There are 8000 images in 'original/train/real' directory.
# There are 0 images in 'original/val' directory.
# There are 0 images in 'original/val/fake' directory.
# There are 1000 images in 'original/val/real' directory.

# %% [markdown]
# ### Fake Dataset Curation

# %%
# !git clone https://github.com/NVlabs/stylegan3.git
# Out:
# Cloning into 'stylegan3'...
# remote: Enumerating objects: 212, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 212 (delta 0), reused 1 (delta 0), pack-reused 207
# Receiving objects: 100% (212/212), 4.17 MiB | 30.30 MiB/s, done.
# Resolving deltas: 100% (99/99), done.

# %%
import os
os.chdir('stylegan3/')

# %%
# !sudo apt-get install ninja-build
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   ninja-build
# 0 upgraded, 1 newly installed, 0 to remove and 19 not upgraded.
# Need to get 111 kB of archives.
# After this operation, 358 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 ninja-build amd64 1.10.1-1 [111 kB]
# Fetched 111 kB in 1s (136 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package ninja-build.
# (Reading database ... 120874 files and directories currently installed.)
# Preparing to unpack .../ninja-build_1.10.1-1_amd64.deb ...
# Unpacking ninja-build (1.10.1-1) ...
# Setting up ninja-build (1.10.1-1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# Generate an image using pre-trained AFHQv2 model ("Ours" in Figure 1, left).
# stylegan3-t-ffhq-1024x1024.pkl
#stylegan3-r-ffhq-1024x1024.pkl
# !python gen_images.py --outdir=out --seeds=0-9999 \
    --network=https://api.ngc.nvidia.com/v2/models/nvidia/research/stylegan3/versions/1/files/stylegan3-r-ffhq-1024x1024.pkl

# %%
# !mv out ../

# %%
os.chdir('../')

# %%
import os
import shutil
from PIL import Image

# Define the base path for the 'original' directory
base_original_dir = 'original'

# Define the directories for train, validation, and test sets
train_dir = os.path.join(base_original_dir, 'train', 'fake')
val_dir = os.path.join(base_original_dir, 'val', 'fake')
test_dir = os.path.join(base_original_dir, 'test', 'fake')

# Create the directories if they don't exist
os.makedirs(train_dir, exist_ok=True)
os.makedirs(val_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

# Source directory containing all synthetic images
source_dir = 'out'

# Function to resize and move images
def resize_and_move(start_index, end_index, source_folder, destination_folder):
    for i in range(start_index, end_index):
        # Adjust for the filename format 'seed0000.png'
        file_name = f"seed{i:04d}.png"
        source_file = os.path.join(source_folder, file_name)

        # Check if the file exists to avoid errors
        if os.path.isfile(source_file):
            # Open the image, resize it, and save it to the destination folder
            with Image.open(source_file) as img:
                img = img.resize((256, 256), Image.BICUBIC)
                img.save(os.path.join(destination_folder, file_name))
            # Optionally delete the original if needed
            # os.remove(source_file)

# Move the first 4000 images to the train directory after resizing
resize_and_move(0, 8000, source_dir, train_dir)

# Move the next 500 images to the validation directory after resizing
resize_and_move(8000, 9000, source_dir, val_dir)

# Move the last 500 images to the test directory after resizing
resize_and_move(9000, 10000, source_dir, test_dir)

print("Synthetic images resized and distributed to train, val, and test directories.")
# Out:
# Synthetic images resized and distributed to train, val, and test directories.

# %%
import os

def count_images_in_directory(directory):
    # Initialize a counter
    count = 0
    # Walk through all files and directories within the given directory
    for root, dirs, files in os.walk(directory):
        # Count the number of PNG files
        count += len([file for file in files if file.endswith('.png')])
        print(f"There are {count} images in '{root}' directory.")
        # Reset the counter after printing out the count for the current directory
        count = 0

# Define the base path for the 'original' directory
base_original_dir = 'original'

# Call the function with the path to the 'original' directory
count_images_in_directory(base_original_dir)
# Out:
# There are 0 images in 'original' directory.
# There are 0 images in 'original/test' directory.
# There are 1000 images in 'original/test/fake' directory.
# There are 1000 images in 'original/test/real' directory.
# There are 0 images in 'original/train' directory.
# There are 8000 images in 'original/train/fake' directory.
# There are 8000 images in 'original/train/real' directory.
# There are 0 images in 'original/val' directory.
# There are 1000 images in 'original/val/fake' directory.
# There are 1000 images in 'original/val/real' directory.

# %% [markdown]
# ### Original Dataset Compiling

# %%
# !zip -r original_dataset_stylegan3_10000.zip original/
# Out:
# Streaming output truncated to the last 5000 lines.
#   adding: original/train/real/00617.png (deflated 0%)
#   adding: original/train/real/07358.png (deflated 0%)
#   adding: original/train/real/01775.png (deflated 0%)
#   adding: original/train/real/02152.png (deflated 0%)
#   adding: original/train/real/04878.png (deflated 0%)
#   adding: original/train/real/03806.png (deflated 0%)
#   adding: original/train/real/06380.png (deflated 0%)
#   adding: original/train/real/00578.png (deflated 0%)
#   adding: original/train/real/04409.png (deflated 0%)
#   adding: original/train/real/00753.png (deflated 0%)
#   adding: original/train/real/06727.png (deflated 0%)
#   adding: original/train/real/05957.png (deflated 0%)
#   adding: original/train/real/04537.png (deflated 0%)
#   adding: original/train/real/01056.png (deflated 0%)
#   adding: original/train/real/07570.png (deflated 0%)
#   adding: original/train/real/00803.png (deflated 0%)
#   adding: original/train/real/05760.png (deflated 0%)
#   adding: original/train/real/06964.png (deflated 0%)
#   adding: original/train/real/00030.png (deflated 0%)
#   adding: original/train/real/07962.png (deflated 0%)
#   adding: original/train/real/04130.png (deflated 0%)
#   adding: original/train/real/00460.png (deflated 0%)
#   adding: original/train/real/04092.png (deflated 0%)
#   adding: original/train/real/01063.png (deflated 0%)
#   adding: original/train/real/02756.png (deflated 0%)
#   adding: original/train/real/07145.png (deflated 0%)
#   adding: original/train/real/06230.png (deflated 0%)
#   adding: original/train/real/07526.png (deflated 0%)
#   adding: original/train/real/01912.png (deflated 0%)
#   adding: original/train/real/05028.png (deflated 0%)
#   adding: original/train/real/03681.png (deflated 0%)
#   adding: original/train/real/03857.png (deflated 0%)
#   adding: original/train/real/06645.png (deflated 0%)
#   adding: original/train/real/05979.png (deflated 0%)
#   adding: original/train/real/00676.png (deflated 0%)
#   adding: original/train/real/07798.png (deflated 0%)
#   adding: original/train/real/00396.png (deflated 0%)
#   adding: original/train/real/06172.png (deflated 0%)
#   adding: original/train/real/07305.png (deflated 0%)
#   adding: original/train/real/03579.png (deflated 0%)
#   adding: original/train/real/06290.png (deflated 0%)
#   adding: original/train/real/04700.png (deflated 0%)
#   adding: original/train/real/03820.png (deflated 0%)
#   adding: original/train/real/01083.png (deflated 0%)
#   adding: original/train/real/01318.png (deflated 0%)
#   adding: original/train/real/04850.png (deflated 0%)
#   adding: original/train/real/02224.png (deflated 0%)
#   adding: original/train/real/02340.png (deflated 0%)
#   adding: original/train/real/04985.png (deflated 0%)
#   adding: original/train/real/05064.png (deflated 0%)
#   adding: original/train/real/01436.png (deflated 0%)
#   adding: original/train/real/06828.png (deflated 0%)
#   adding: original/train/real/00996.png (deflated 0%)
#   adding: original/train/real/04900.png (deflated 0%)
#   adding: original/train/real/01625.png (deflated 0%)
#   adding: original/train/real/05680.png (deflated 0%)
# ...
#   adding: original/val/real/08459.png (deflated 0%)
#   adding: original/val/real/08574.png (deflated 0%)
#   adding: original/val/real/08752.png (deflated 0%)
#   adding: original/val/real/08902.png (deflated 0%)
#   adding: original/val/real/08500.png (deflated 0%)
#   adding: original/val/real/08786.png (deflated 0%)
#   adding: original/val/real/08013.png (deflated 0%)
#   adding: original/val/real/08174.png (deflated 0%)
#   adding: original/val/real/08098.png (deflated 0%)
#   adding: original/val/real/08808.png (deflated 0%)
#   adding: original/val/real/08342.png (deflated 0%)
#   adding: original/val/real/08244.png (deflated 0%)
#   adding: original/val/real/08516.png (deflated 0%)
#   adding: original/val/real/08507.png (deflated 0%)
#   adding: original/val/real/08405.png (deflated 0%)
#   adding: original/val/real/08408.png (deflated 0%)
#   adding: original/val/real/08797.png (deflated 0%)
#   adding: original/val/real/08358.png (deflated 0%)
#   adding: original/val/real/08012.png (deflated 0%)
#   adding: original/val/real/08785.png (deflated 0%)
#   adding: original/val/real/08284.png (deflated 0%)
#   adding: original/val/real/08065.png (deflated 0%)
#   adding: original/val/real/08048.png (deflated 0%)
#   adding: original/val/real/08437.png (deflated 0%)
#   adding: original/val/real/08827.png (deflated 0%)
#   adding: original/val/real/08798.png (deflated 0%)
#   adding: original/val/real/08852.png (deflated 0%)
#   adding: original/val/real/08381.png (deflated 0%)
#   adding: original/val/real/08807.png (deflated 0%)
#   adding: original/val/real/08607.png (deflated 0%)
#   adding: original/val/real/08337.png (deflated 0%)
#   adding: original/val/real/08969.png (deflated 0%)
#   adding: original/val/real/08928.png (deflated 0%)
#   adding: original/val/real/08471.png (deflated 0%)
#   adding: original/val/real/08563.png (deflated 0%)
#   adding: original/val/real/08208.png (deflated 0%)
#   adding: original/val/real/08068.png (deflated 0%)
#   adding: original/val/real/08688.png (deflated 0%)
#   adding: original/val/real/08782.png (deflated 0%)
#   adding: original/val/real/08699.png (deflated 0%)
#   adding: original/val/real/08149.png (deflated 0%)
#   adding: original/val/real/08783.png (deflated 0%)
#   adding: original/val/real/08360.png (deflated 0%)
#   adding: original/val/real/08567.png (deflated 0%)
#   adding: original/val/real/08416.png (deflated 0%)
#   adding: original/val/real/08766.png (deflated 0%)
#   adding: original/val/real/08512.png (deflated 0%)
#   adding: original/val/real/08312.png (deflated 0%)
#   adding: original/val/real/08086.png (deflated 0%)
#   adding: original/val/real/08967.png (deflated 0%)
#   adding: original/val/real/08133.png (deflated 0%)
#   adding: original/val/real/08472.png (deflated 0%)
#   adding: original/val/real/08322.png (deflated 0%)
#   adding: original/val/real/08972.png (deflated 0%)
#   adding: original/val/real/08450.png (deflated 0%)
#   adding: original/val/real/08082.png (deflated 0%)
#   adding: original/val/real/08224.png (deflated 0%)
#   adding: original/val/real/08975.png (deflated 0%)
#   adding: original/val/real/08957.png (deflated 0%)
#   adding: original/val/real/08665.png (deflated 0%)
#   adding: original/val/real/08299.png (deflated 0%)
#   adding: original/val/real/08582.png (deflated 0%)
#   adding: original/val/real/08142.png (deflated 0%)
#   adding: original/val/real/08111.png (deflated 0%)
#   adding: original/val/real/08198.png (deflated 0%)
#   adding: original/val/real/08933.png (deflated 0%)
#   adding: original/val/real/08104.png (deflated 0%)
#   adding: original/val/real/08525.png (deflated 0%)
#   adding: original/val/real/08764.png (deflated 0%)
#   adding: original/val/real/08414.png (deflated 0%)
#   adding: original/val/real/08217.png (deflated 0%)
#   adding: original/val/real/08401.png (deflated 0%)
#   adding: original/val/real/08945.png (deflated 0%)
#   adding: original/val/real/08073.png (deflated 0%)
#   adding: original/val/real/08633.png (deflated 0%)
#   adding: original/val/real/08676.png (deflated 0%)
#   adding: original/val/real/08584.png (deflated 0%)
#   adding: original/val/real/08199.png (deflated 0%)
#   adding: original/val/real/08030.png (deflated 0%)
#   adding: original/val/real/08041.png (deflated 0%)
#   adding: original/val/real/08429.png (deflated 0%)
#   adding: original/val/real/08112.png (deflated 0%)
#   adding: original/val/real/08353.png (deflated 0%)
#   adding: original/val/real/08286.png (deflated 0%)
#   adding: original/val/real/08987.png (deflated 0%)
#   adding: original/val/real/08553.png (deflated 0%)
#   adding: original/val/real/08478.png (deflated 0%)
#   adding: original/val/real/08709.png (deflated 0%)
#   adding: original/val/real/08690.png (deflated 0%)
#   adding: original/val/real/08470.png (deflated 0%)
#   adding: original/val/real/08813.png (deflated 0%)
#   adding: original/val/real/08883.png (deflated 0%)
#   adding: original/val/real/08806.png (deflated 0%)
#   adding: original/val/real/08230.png (deflated 0%)
#   adding: original/val/real/08604.png (deflated 0%)
#   adding: original/val/real/08304.png (deflated 0%)
#   adding: original/val/real/08100.png (deflated 0%)
#   adding: original/val/real/08948.png (deflated 0%)
#   adding: original/val/real/08079.png (deflated 0%)
#   adding: original/val/real/08970.png (deflated 0%)
#   adding: original/val/real/08860.png (deflated 0%)
#   adding: original/val/real/08892.png (deflated 0%)
#   adding: original/val/real/08818.png (deflated 0%)
#   adding: original/val/real/08282.png (deflated 0%)
#   adding: original/val/real/08053.png (deflated 0%)
#   adding: original/val/real/08765.png (deflated 0%)
#   adding: original/val/real/08614.png (deflated 0%)
#   adding: original/val/real/08321.png (deflated 0%)
#   adding: original/val/real/08140.png (deflated 0%)
#   adding: original/val/real/08186.png (deflated 0%)
#   adding: original/val/real/08349.png (deflated 0%)
#   adding: original/val/real/08184.png (deflated 0%)
#   adding: original/val/real/08448.png (deflated 0%)
#   adding: original/val/real/08511.png (deflated 0%)
#   adding: original/val/real/08986.png (deflated 0%)
#   adding: original/val/real/08560.png (deflated 0%)
#   adding: original/val/real/08062.png (deflated 0%)
#   adding: original/val/real/08628.png (deflated 0%)
#   adding: original/val/real/08359.png (deflated 0%)
#   adding: original/val/real/08189.png (deflated 0%)
#   adding: original/val/real/08229.png (deflated 0%)
#   adding: original/val/real/08615.png (deflated 0%)
#   adding: original/val/real/08518.png (deflated 0%)
#   adding: original/val/real/08658.png (deflated 0%)
#   adding: original/val/real/08486.png (deflated 0%)
#   adding: original/val/real/08419.png (deflated 0%)
#   adding: original/val/real/08695.png (deflated 0%)
#   adding: original/val/real/08869.png (deflated 0%)
#   adding: original/val/real/08376.png (deflated 0%)
#   adding: original/val/real/08110.png (deflated 0%)
#   adding: original/val/real/08581.png (deflated 0%)
#   adding: original/val/real/08704.png (deflated 0%)
#   adding: original/val/real/08919.png (deflated 0%)
#   adding: original/val/real/08872.png (deflated 0%)
#   adding: original/val/real/08058.png (deflated 0%)
#   adding: original/val/real/08382.png (deflated 0%)
#   adding: original/val/real/08505.png (deflated 0%)
#   adding: original/val/real/08585.png (deflated 0%)
#   adding: original/val/real/08330.png (deflated 0%)
#   adding: original/val/real/08671.png (deflated 0%)
#   adding: original/val/real/08307.png (deflated 0%)
#   adding: original/val/real/08165.png (deflated 0%)
#   adding: original/val/real/08328.png (deflated 0%)
#   adding: original/val/real/08108.png (deflated 0%)
#   adding: original/val/real/08292.png (deflated 0%)
#   adding: original/val/real/08155.png (deflated 0%)
#   adding: original/val/real/08659.png (deflated 0%)
#   adding: original/val/real/08772.png (deflated 0%)
#   adding: original/val/real/08680.png (deflated 0%)
#   adding: original/val/real/08701.png (deflated 0%)
#   adding: original/val/real/08640.png (deflated 0%)
#   adding: original/val/real/08354.png (deflated 0%)
#   adding: original/val/real/08222.png (deflated 0%)
#   adding: original/val/real/08363.png (deflated 0%)
#   adding: original/val/real/08485.png (deflated 0%)
#   adding: original/val/real/08643.png (deflated 0%)
#   adding: original/val/real/08001.png (deflated 0%)
#   adding: original/val/real/08841.png (deflated 0%)
#   adding: original/val/real/08677.png (deflated 0%)
#   adding: original/val/real/08415.png (deflated 0%)
#   adding: original/val/real/08589.png (deflated 0%)
#   adding: original/val/real/08747.png (deflated 0%)
#   adding: original/val/real/08225.png (deflated 0%)
#   adding: original/val/real/08959.png (deflated 0%)
#   adding: original/val/real/08646.png (deflated 0%)
#   adding: original/val/real/08802.png (deflated 0%)
#   adding: original/val/real/08444.png (deflated 0%)
#   adding: original/val/real/08831.png (deflated 0%)
#   adding: original/val/real/08787.png (deflated 0%)
#   adding: original/val/real/08228.png (deflated 0%)
#   adding: original/val/real/08600.png (deflated 0%)
#   adding: original/val/real/08357.png (deflated 0%)
#   adding: original/val/real/08290.png (deflated 0%)
#   adding: original/val/real/08220.png (deflated 0%)
#   adding: original/val/real/08000.png (deflated 0%)
#   adding: original/val/real/08788.png (deflated 0%)
#   adding: original/val/real/08226.png (deflated 0%)
#   adding: original/val/real/08014.png (deflated 0%)
#   adding: original/val/real/08641.png (deflated 0%)
#   adding: original/val/real/08259.png (deflated 0%)
#   adding: original/val/real/08020.png (deflated 0%)
#   adding: original/val/real/08264.png (deflated 0%)
#   adding: original/val/real/08314.png (deflated 0%)
#   adding: original/val/real/08262.png (deflated 0%)
#   adding: original/val/real/08662.png (deflated 0%)
#   adding: original/val/real/08498.png (deflated 0%)
#   adding: original/val/real/08163.png (deflated 0%)
#   adding: original/val/real/08750.png (deflated 0%)
#   adding: original/val/real/08901.png (deflated 0%)
#   adding: original/val/real/08368.png (deflated 0%)
#   adding: original/val/real/08176.png (deflated 0%)
#   adding: original/val/real/08519.png (deflated 0%)
#   adding: original/val/real/08985.png (deflated 0%)
#   adding: original/val/real/08602.png (deflated 0%)
#   adding: original/val/real/08586.png (deflated 0%)
#   adding: original/val/real/08293.png (deflated 0%)
#   adding: original/val/real/08530.png (deflated 0%)
#   adding: original/val/real/08143.png (deflated 0%)
#   adding: original/val/real/08209.png (deflated 0%)
#   adding: original/val/real/08960.png (deflated 0%)
#   adding: original/val/real/08102.png (deflated 0%)
#   adding: original/val/real/08417.png (deflated 0%)
#   adding: original/val/real/08617.png (deflated 0%)
#   adding: original/val/real/08488.png (deflated 0%)
#   adding: original/val/real/08103.png (deflated 0%)
#   adding: original/val/real/08087.png (deflated 0%)
#   adding: original/val/real/08973.png (deflated 0%)
#   adding: original/val/real/08443.png (deflated 0%)
#   adding: original/val/real/08060.png (deflated 0%)
#   adding: original/val/real/08396.png (deflated 0%)
#   adding: original/val/real/08334.png (deflated 0%)
#   adding: original/val/real/08531.png (deflated 0%)
#   adding: original/val/real/08711.png (deflated 0%)
#   adding: original/val/real/08105.png (deflated 0%)
#   adding: original/val/real/08277.png (deflated 0%)
#   adding: original/val/real/08849.png (deflated 0%)
#   adding: original/val/real/08261.png (deflated 0%)
#   adding: original/val/real/08868.png (deflated 0%)
#   adding: original/val/real/08248.png (deflated 0%)
#   adding: original/val/real/08715.png (deflated 0%)
#   adding: original/val/real/08063.png (deflated 0%)
#   adding: original/val/real/08536.png (deflated 0%)
#   adding: original/val/real/08067.png (deflated 0%)
#   adding: original/val/real/08564.png (deflated 0%)
#   adding: original/val/real/08364.png (deflated 0%)
#   adding: original/val/real/08955.png (deflated 0%)
#   adding: original/val/real/08132.png (deflated 0%)
#   adding: original/val/real/08595.png (deflated 0%)
#   adding: original/val/real/08780.png (deflated 0%)
#   adding: original/val/real/08267.png (deflated 0%)
#   adding: original/val/real/08455.png (deflated 0%)
#   adding: original/val/real/08625.png (deflated 0%)
#   adding: original/val/real/08007.png (deflated 0%)
#   adding: original/val/real/08481.png (deflated 0%)
#   adding: original/val/real/08864.png (deflated 0%)
#   adding: original/val/real/08550.png (deflated 0%)
#   adding: original/val/real/08548.png (deflated 0%)
#   adding: original/val/real/08074.png (deflated 0%)
#   adding: original/val/real/08245.png (deflated 0%)
#   adding: original/val/real/08213.png (deflated 0%)
#   adding: original/val/real/08950.png (deflated 0%)
#   adding: original/val/real/08656.png (deflated 0%)
#   adding: original/val/real/08492.png (deflated 0%)

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp original_dataset_stylegan3_10000.zip /content/drive/MyDrive/

# %% [markdown]
# ### Initial Deep Learning Model Benchmarking

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model

# Load the pre-trained ResNet50 model
base_model = ResNet50(include_top=False, input_shape=(256, 256, 3))

# Freeze the layers of the base model
for layer in base_model.layers:
    layer.trainable = True

# Add new top layers
x = GlobalAveragePooling2D()(base_model.output)
predictions = Dense(2, activation='softmax')(x)  # Assuming binary classification (real vs fake)
model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Setup data generators
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    'original/train/',
    target_size=(256, 256),
    batch_size=32,
    class_mode='categorical'
)

validation_generator = val_datagen.flow_from_directory(
    'original/val/',
    target_size=(256, 256),
    batch_size=32,
    class_mode='categorical'
)

# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size,
    epochs=10
)

# Evaluate the model on the test set
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    'original/test/',
    target_size=(256, 256),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)

# Evaluate on test data
results = model.evaluate(test_generator)
print(f"Test Loss: {results[0]}, Test Accuracy: {results[1]}")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 0s 0us/step
# Found 16000 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.
# Epoch 1/10
# 500/500 [==============================] - 260s 431ms/step - loss: 0.7276 - accuracy: 0.5211 - val_loss: 0.6938 - val_accuracy: 0.4990
# Epoch 2/10
# 500/500 [==============================] - 218s 437ms/step - loss: 0.6808 - accuracy: 0.5723 - val_loss: 0.6695 - val_accuracy: 0.5897
# Epoch 3/10
# 500/500 [==============================] - 217s 434ms/step - loss: 0.6497 - accuracy: 0.6127 - val_loss: 3.7181 - val_accuracy: 0.5005
# Epoch 4/10
# 500/500 [==============================] - 219s 437ms/step - loss: 0.6090 - accuracy: 0.6575 - val_loss: 0.7143 - val_accuracy: 0.5025
# Epoch 5/10
# 500/500 [==============================] - 219s 438ms/step - loss: 0.5605 - accuracy: 0.6945 - val_loss: 0.6955 - val_accuracy: 0.5212
# Epoch 6/10
# 500/500 [==============================] - 219s 438ms/step - loss: 0.5059 - accuracy: 0.7372 - val_loss: 0.6398 - val_accuracy: 0.6507
# Epoch 7/10
# 500/500 [==============================] - 219s 437ms/step - loss: 0.4599 - accuracy: 0.7666 - val_loss: 0.7729 - val_accuracy: 0.5096
# Epoch 8/10
# 500/500 [==============================] - 218s 436ms/step - loss: 0.3954 - accuracy: 0.8059 - val_loss: 0.7659 - val_accuracy: 0.5791
# Epoch 9/10
# 406/500 [=======================>......] - ETA: 39s - loss: 0.3375 - accuracy: 0.8420
